# %% [markdown]
# ## 导入工具包

# %%
import numpy as np
from PIL import Image

import os.path as osp
from tqdm import tqdm

import mmcv
import mmengine
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 数据集图片和标注路径
data_root = 'Glomeruli-dataset'
img_dir = 'images'
ann_dir = 'masks'

# 类别和对应的颜色
classes = ('background', 'glomeruili')
palette = [[128, 128, 128], [151, 189, 8]]

# %% [markdown]
# ## 修改数据集类（指定图像扩展名）

# %% [markdown]
# After downloading the data, we need to implement `load_annotations` function in the new dataset class `StanfordBackgroundDataset`.

# %%
from mmseg.registry import DATASETS
from mmseg.datasets import BaseSegDataset

@DATASETS.register_module()
class StanfordBackgroundDataset(BaseSegDataset):
  METAINFO = dict(classes = classes, palette = palette)
  def __init__(self, **kwargs):
    super().__init__(img_suffix='.png', seg_map_suffix='.png', **kwargs)

# %% [markdown]
# 文档：https://github.com/open-mmlab/mmsegmentation/blob/master/docs/en/tutorials/customize_datasets.md#customize-datasets-by-reorganizing-data

# %% [markdown]
# ## 修改config配置文件

# %%
# 下载 config 文件 和 预训练模型checkpoint权重文件
# !mim download mmsegmentation --config pspnet_r50-d8_4xb2-40k_cityscapes-512x1024 --dest .
# Out:
# processing pspnet_r50-d8_4xb2-40k_cityscapes-512x1024...
# pspnet_r50-d8_512x1024_40k_cityscapes_20200605_003338-2966598c.pth exists in /home/featurize/work/MMSegmentation_Tutorials-main/20230215/【D1】Kaggle代码实战-肾小球切片语义分割
# Successfully dumped pspnet_r50-d8_4xb2-40k_cityscapes-512x1024.py to /home/featurize/work/MMSegmentation_Tutorials-main/20230215/【D1】Kaggle代码实战-肾小球切片语义分割

# %%
from mmengine import Config
cfg = Config.fromfile('./mmsegmentation/configs/pspnet/pspnet_r50-d8_4xb2-40k_cityscapes-512x1024.py')

# %%
cfg.norm_cfg = dict(type='BN', requires_grad=True) # 只使用GPU时，BN取代SyncBN
cfg.crop_size = (256, 256)
cfg.model.data_preprocessor.size = cfg.crop_size

#统一设置norm_cfg
cfg.model.backbone.norm_cfg = cfg.norm_cfg
cfg.model.decode_head.norm_cfg = cfg.norm_cfg
cfg.model.auxiliary_head.norm_cfg = cfg.norm_cfg
# 修改分类数
cfg.model.decode_head.num_classes = 2
cfg.model.auxiliary_head.num_classes = 2


# 修改decode_head的损失函数为Dice+交叉熵组合
cfg.model.decode_head.loss_decode = [
    dict(type='CrossEntropyLoss', loss_weight=1.0, use_sigmoid=False),  # 交叉熵
    dict(type='DiceLoss', loss_weight=0.5) 
]

# 修改auxiliary_head的损失函数
cfg.model.auxiliary_head.loss_decode = [
    dict(type='CrossEntropyLoss', loss_weight=0.4, use_sigmoid=False),
    dict(type='DiceLoss', loss_weight=0.2)  
]

# 修改数据集的 type 和 root
cfg.dataset_type = 'StanfordBackgroundDataset'
cfg.data_root = data_root

cfg.train_dataloader.batch_size = 8

cfg.train_pipeline = [
    dict(type='LoadImageFromFile'),
    dict(type='LoadAnnotations'),
    dict(type='RandomResize', scale=(320, 240), ratio_range=(0.5, 2.0), keep_ratio=True),
    dict(type='RandomCrop', crop_size=cfg.crop_size, cat_max_ratio=0.75),
    dict(type='RandomFlip', prob=0.5),
    dict(type='PackSegInputs')
]

cfg.test_pipeline = [
    dict(type='LoadImageFromFile'),
    dict(type='Resize', scale=(320, 240), keep_ratio=True),
    # add loading annotation after ``Resize`` because ground truth
    # does not need to do resize data transform
    dict(type='LoadAnnotations'),
    dict(type='PackSegInputs')
]


cfg.train_dataloader.dataset.type = cfg.dataset_type
cfg.train_dataloader.dataset.data_root = cfg.data_root
cfg.train_dataloader.dataset.data_prefix = dict(img_path=img_dir, seg_map_path=ann_dir)
cfg.train_dataloader.dataset.pipeline = cfg.train_pipeline
cfg.train_dataloader.dataset.ann_file = 'splits/train.txt'

cfg.val_dataloader.dataset.type = cfg.dataset_type
cfg.val_dataloader.dataset.data_root = cfg.data_root
cfg.val_dataloader.dataset.data_prefix = dict(img_path=img_dir, seg_map_path=ann_dir)
cfg.val_dataloader.dataset.pipeline = cfg.test_pipeline
cfg.val_dataloader.dataset.ann_file = 'splits/val.txt'

cfg.test_dataloader = cfg.val_dataloader

# 验证 Evaluator
# val_evaluator = dict(type='IoUMetric', iou_metrics=['mIoU', 'mDice', 'mFscore'])
val_evaluator = dict(
    type='IoUMetric',
    iou_metrics=['mIoU', 'mDice', 'mFscore'],
    output_dir='val_metrics',  # 单独保存验证结果
    format_only=False,
    print_results=True  # 强制打印所有结果
)


# ------------------ 新增数据集元信息 ------------------
cfg.metainfo = {
    'classes': ('background', 'glomeruili'),  # 必须与您的标注类别一致
    'palette': [[0, 0, 0], [255, 0, 0]]     # 颜色配置（可选）
}

# ------------------ 修改评估器配置 ------------------
cfg.val_evaluator = dict(
    type='IoUMetric',
    iou_metrics=['mIoU', 'mDice', 'mFscore'],  # 明确指定所有指标
    output_dir='val_metrics',                  # 评估结果保存路径
    format_only=False,
    # 关键：注入数据集类别信息
    dataset_meta=cfg.metainfo  
)

# ------------------ 将metainfo注入所有数据集 ------------------
for ds_key in ['train_dataloader', 'val_dataloader', 'test_dataloader']:
    cfg[ds_key]['dataset']['metainfo'] = cfg.metainfo




# 测试 Evaluator
test_evaluator = val_evaluator


# 载入预训练模型权重
cfg.load_from = 'pspnet_r50-d8_512x1024_40k_cityscapes_20200605_003338-2966598c.pth'

# 工作目录
cfg.work_dir = './work_dirs/tutorial'

cfg.default_hooks = dict(
    checkpoint=dict(
        type='CheckpointHook',
        interval = 1000 ,
        by_epoch=False,
        filename_tmpl='CE+Dice{}.pth',  # 文件名模板（{} 会被替换为 epoch 或 iter）
        save_best='mIoU'
    )
)

# ------------------ 优化器与学习率配置 ------------------
optim_wrapper = dict(
    optimizer=dict(type='SGD', lr=0.01, momentum=0.9, weight_decay=0.0005),
)

# ------------------ 学习率调度器（含预热） ------------------
param_scheduler = [
    # Warmup Phase (0~500 iterations)
    dict(
        type='LinearLR',
        start_factor=0.1,
        end=500,
        by_epoch=False,
    ),
    # Main Phase (500~30000 iterations)
    dict(
        type='PolyLR',
        power=0.9,
        eta_min=1e-4,
        begin=500,
        end=30000,
        by_epoch=False
    )
]
# 将 param_scheduler 赋值给 cfg
cfg.param_scheduler = param_scheduler  # 关键步骤！

#cfg.default_hooks['checkpoint']['max_keep_ckpts'] = 1

# 训练总迭代次数
cfg.train_cfg.max_iters = 30000  

# 验证频率 (每N次迭代)
cfg.train_cfg.val_interval = 500  # 约每2个epoch验证一次

# 日志记录频率 
#cfg.default_hooks.logger.interval = 50  # 每50iter记录一次

# 模型保存频率
cfg.default_hooks.checkpoint.interval = 2000  # 每800iter保存一次

# 随机数种子
cfg['randomness'] = dict(seed=0)

# %%
from mmseg.apis import init_model
model = init_model(cfg, device='cuda')

# 打印评估器配置
print("当前评估器配置：", cfg.val_evaluator)
# 应输出包含 'mDice' 和 'mFscore' 的配置
# Out:
# /home/featurize/work/MMSegmentation_Tutorials-main/20230215/mmsegmentation/mmseg/models/decode_heads/decode_head.py:120: UserWarning: For binary segmentation, we suggest using`out_channels = 1` to define the outputchannels of segmentor, and use `threshold`to convert `seg_logits` into a predictionapplying a threshold
#   warnings.warn('For binary segmentation, we suggest using'
# /home/featurize/work/MMSegmentation_Tutorials-main/20230215/mmsegmentation/mmseg/models/losses/cross_entropy_loss.py:251: UserWarning: Default ``avg_non_ignore`` is False, if you would like to ignore the certain label and average loss over non-ignore labels, which is the same with PyTorch official cross_entropy, set ``avg_non_ignore=True``.
#   'Default ``avg_non_ignore`` is False, if you would like to '
# 当前评估器配置： {'type': 'IoUMetric', 'iou_metrics': ['mIoU', 'mDice', 'mFscore'], 'output_dir': 'val_metrics', 'format_only': False, 'dataset_meta': {'classes': ('background', 'glomeruili'), 'palette': [[0, 0, 0], [255, 0, 0]]}}

# %%
#from mmengine.runner import Runner
#runner = Runner.from_cfg(cfg)
#print("验证集类别信息：", runner.val_dataloader.dataset.metainfo)
# 应输出：{'classes': ['background', 'glomeruli'], ...}

# %% [markdown]
# ## 查看完整config配置文件

# %%
print(cfg.pretty_text)
# Out:
# crop_size = (
#     256,
#     256,
# )
# data_preprocessor = dict(
#     bgr_to_rgb=True,
#     mean=[
#         123.675,
#         116.28,
#         103.53,
#     ],
#     pad_val=0,
#     seg_pad_val=255,
#     size=(
#         512,
#         1024,
#     ),
#     std=[
#         58.395,
#         57.12,
#         57.375,
#     ],
#     type='SegDataPreProcessor')
# data_root = 'Glomeruli-dataset'
# dataset_type = 'StanfordBackgroundDataset'
# default_hooks = dict(
#     checkpoint=dict(
#         by_epoch=False,
#         filename_tmpl='CE+Dice{}.pth',
#         interval=2000,
#         save_best='mIoU',
#         type='CheckpointHook'))
# default_scope = 'mmseg'
# env_cfg = dict(
#     cudnn_benchmark=True,
#     dist_cfg=dict(backend='nccl'),
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0))
# img_ratios = [
#     0.5,
#     0.75,
#     1.0,
#     1.25,
#     1.5,
#     1.75,
# ]
# load_from = 'pspnet_r50-d8_512x1024_40k_cityscapes_20200605_003338-2966598c.pth'
# log_level = 'INFO'
# log_processor = dict(by_epoch=False)
# metainfo = dict(
#     classes=(
#         'background',
#         'glomeruili',
#     ),
#     palette=[
#         [
#             0,
#             0,
#             0,
#         ],
#         [
#             255,
#             0,
#             0,
#         ],
#     ])
# model = dict(
#     auxiliary_head=dict(
#         align_corners=False,
#         channels=256,
#         concat_input=False,
#         dropout_ratio=0.1,
#         in_channels=1024,
#         in_index=2,
#         loss_decode=[
#             dict(loss_weight=0.4, type='CrossEntropyLoss', use_sigmoid=False),
#             dict(loss_weight=0.2, type='DiceLoss'),
#         ],
#         norm_cfg=dict(requires_grad=True, type='BN'),
#         num_classes=2,
#         num_convs=1,
#         type='FCNHead'),
#     backbone=dict(
#         contract_dilation=True,
#         depth=50,
#         dilations=(
#             1,
#             1,
#             2,
#             4,
#         ),
#         norm_cfg=dict(requires_grad=True, type='BN'),
#         norm_eval=False,
#         num_stages=4,
#         out_indices=(
#             0,
#             1,
#             2,
#             3,
#         ),
#         strides=(
#             1,
#             2,
#             1,
#             1,
#         ),
#         style='pytorch',
#         type='ResNetV1c'),
#     data_preprocessor=dict(
#         bgr_to_rgb=True,
#         mean=[
#             123.675,
#             116.28,
#             103.53,
#         ],
#         pad_val=0,
#         seg_pad_val=255,
#         size=(
#             256,
#             256,
#         ),
#         std=[
#             58.395,
#             57.12,
#             57.375,
#         ],
#         type='SegDataPreProcessor'),
#     decode_head=dict(
#         align_corners=False,
#         channels=512,
#         dropout_ratio=0.1,
#         in_channels=2048,
#         in_index=3,
#         loss_decode=[
#             dict(loss_weight=1.0, type='CrossEntropyLoss', use_sigmoid=False),
#             dict(loss_weight=0.5, type='DiceLoss'),
#         ],
#         norm_cfg=dict(requires_grad=True, type='BN'),
#         num_classes=2,
#         pool_scales=(
#             1,
#             2,
#             3,
#             6,
#         ),
#         type='PSPHead'),
#     pretrained=None,
#     test_cfg=dict(mode='whole'),
#     train_cfg=None,
#     type='EncoderDecoder')
# norm_cfg = dict(requires_grad=True, type='BN')
# optim_wrapper = dict(
#     clip_grad=None,
#     optimizer=dict(lr=0.01, momentum=0.9, type='SGD', weight_decay=0.0005),
#     type='OptimWrapper')
# optimizer = dict(lr=0.01, momentum=0.9, type='SGD', weight_decay=0.0005)
# param_scheduler = [
#     dict(by_epoch=False, end=500, start_factor=0.1, type='LinearLR'),
#     dict(
#         begin=500,
#         by_epoch=False,
#         end=30000,
#         eta_min=0.0001,
#         power=0.9,
#         type='PolyLR'),
# ]
# randomness = dict(seed=0)
# resume = False
# test_cfg = dict(type='TestLoop')
# test_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='splits/val.txt',
#         data_prefix=dict(img_path='images', seg_map_path='masks'),
#         data_root='Glomeruli-dataset',
#         metainfo=dict(
#             classes=(
#                 'background',
#                 'glomeruili',
#             ),
#             palette=[
#                 [
#                     0,
#                     0,
#                     0,
#                 ],
#                 [
#                     255,
#                     0,
#                     0,
#                 ],
#             ]),
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 320,
#                 240,
#             ), type='Resize'),
#             dict(type='LoadAnnotations'),
#             dict(type='PackSegInputs'),
#         ],
#         type='StanfordBackgroundDataset'),
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# test_evaluator = dict(
#     iou_metrics=[
#         'mIoU',
#     ], type='IoUMetric')
# test_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(keep_ratio=True, scale=(
#         320,
#         240,
#     ), type='Resize'),
#     dict(type='LoadAnnotations'),
#     dict(type='PackSegInputs'),
# ]
# train_cfg = dict(max_iters=30000, type='IterBasedTrainLoop', val_interval=500)
# train_dataloader = dict(
#     batch_size=8,
#     dataset=dict(
#         ann_file='splits/train.txt',
#         data_prefix=dict(img_path='images', seg_map_path='masks'),
#         data_root='Glomeruli-dataset',
#         metainfo=dict(
#             classes=(
#                 'background',
#                 'glomeruili',
#             ),
#             palette=[
#                 [
#                     0,
#                     0,
#                     0,
#                 ],
#                 [
#                     255,
#                     0,
#                     0,
#                 ],
#             ]),
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='LoadAnnotations'),
#             dict(
#                 keep_ratio=True,
#                 ratio_range=(
#                     0.5,
#                     2.0,
#                 ),
#                 scale=(
#                     320,
#                     240,
#                 ),
#                 type='RandomResize'),
#             dict(
#                 cat_max_ratio=0.75, crop_size=(
#                     256,
#                     256,
#                 ), type='RandomCrop'),
#             dict(prob=0.5, type='RandomFlip'),
#             dict(type='PackSegInputs'),
#         ],
#         type='StanfordBackgroundDataset'),
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=True, type='InfiniteSampler'))
# train_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='LoadAnnotations'),
#     dict(
#         keep_ratio=True,
#         ratio_range=(
#             0.5,
#             2.0,
#         ),
#         scale=(
#             320,
#             240,
#         ),
#         type='RandomResize'),
#     dict(cat_max_ratio=0.75, crop_size=(
#         256,
#         256,
#     ), type='RandomCrop'),
#     dict(prob=0.5, type='RandomFlip'),
#     dict(type='PackSegInputs'),
# ]
# tta_model = dict(type='SegTTAModel')
# tta_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(
#         transforms=[
#             [
#                 dict(keep_ratio=True, scale_factor=0.5, type='Resize'),
#                 dict(keep_ratio=True, scale_factor=0.75, type='Resize'),
#                 dict(keep_ratio=True, scale_factor=1.0, type='Resize'),
#                 dict(keep_ratio=True, scale_factor=1.25, type='Resize'),
#                 dict(keep_ratio=True, scale_factor=1.5, type='Resize'),
#                 dict(keep_ratio=True, scale_factor=1.75, type='Resize'),
#             ],
#             [
#                 dict(direction='horizontal', prob=0.0, type='RandomFlip'),
#                 dict(direction='horizontal', prob=1.0, type='RandomFlip'),
#             ],
#             [
#                 dict(type='LoadAnnotations'),
#             ],
#             [
#                 dict(type='PackSegInputs'),
#             ],
#         ],
#         type='TestTimeAug'),
# ]
# val_cfg = dict(type='ValLoop')
# val_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='splits/val.txt',
#         data_prefix=dict(img_path='images', seg_map_path='masks'),
#         data_root='Glomeruli-dataset',
#         metainfo=dict(
#             classes=(
#                 'background',
#                 'glomeruili',
#             ),
#             palette=[
#                 [
#                     0,
#                     0,
#                     0,
#                 ],
#                 [
#                     255,
#                     0,
#                     0,
#                 ],
#             ]),
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 320,
#                 240,
#             ), type='Resize'),
#             dict(type='LoadAnnotations'),
#             dict(type='PackSegInputs'),
#         ],
#         type='StanfordBackgroundDataset'),
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# val_evaluator = dict(
#     dataset_meta=dict(
#         classes=(
#             'background',
#             'glomeruili',
#         ),
#         palette=[
#             [
#                 0,
#                 0,
#                 0,
#             ],
#             [
#                 255,
#                 0,
#                 0,
#             ],
#         ]),
#     format_only=False,
#     iou_metrics=[
#         'mIoU',
#         'mDice',
#         'mFscore',
#     ],
#     output_dir='val_metrics',
#     type='IoUMetric')
# vis_backends = [
#     dict(type='LocalVisBackend'),
# ]
# visualizer = dict(
#     name='visualizer',
#     type='SegLocalVisualizer',
#     vis_backends=[
#         dict(type='LocalVisBackend'),
#     ])
# work_dir = './work_dirs/tutorial'

# %% [markdown]
# ## 保存config配置文件

# %%
cfg.dump('new_cfg2.py')

# %% [markdown]
# ## 准备训练

# %%
from mmengine.runner import Runner
from mmseg.utils import register_all_modules

# register all modules in mmseg into the registries
# do not init the default scope here because it will be init in the runner
register_all_modules(init_default_scope=False)
runner = Runner.from_cfg(cfg)
# Out:
# 05/14 02:42:26 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.7.10 (default, Jun  4 2021, 14:48:32) [GCC 7.5.0]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 0
#     GPU 0: NVIDIA GeForce RTX 3060
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 11.2, V11.2.152
#     GCC: gcc (Ubuntu 9.3.0-17ubuntu1~20.04) 9.3.0
#     PyTorch: 1.10.1+cu113
#     PyTorch compiling details: PyTorch built with:
#   - GCC 7.3
#   - C++ Version: 201402
#   - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.2.3 (Git Hash 7336ca9f055cf1bfa13efb658fe15dc9b41f0740)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.3
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86
#   - CuDNN 8.2
#   - Magma 2.5.2
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.3, CUDNN_VERSION=8.2.0, CXX_COMPILER=/opt/rh/devtoolset-7/root/usr/bin/c++, CXX_FLAGS= -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -fopenmp -DNDEBUG -DUSE_KINETO -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -DEDGE_PROFILER_USE_KINETO -O2 -fPIC -Wno-narrowing -Wall -Wextra -Werror=return-type -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wno-sign-compare -Wno-unused-parameter -Wno-unused-variable -Wno-unused-function -Wno-unused-result -Wno-unused-local-typedefs -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_VERSION=1.10.1, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=ON, USE_NNPACK=ON, USE_OPENMP=ON,
#
#     TorchVision: 0.11.2+cu113
#     OpenCV: 4.5.4
#     MMEngine: 0.10.7
#
# Runtime environment:
#     cudnn_benchmark: True
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: 0
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 05/14 02:42:27 - mmengine - INFO - Config:
# crop_size = (
#     256,
#     256,
# )
# data_preprocessor = dict(
#     bgr_to_rgb=True,
#     mean=[
#         123.675,
#         116.28,
#         103.53,
#     ],
#     pad_val=0,
#     seg_pad_val=255,
#     size=(
#         512,
#         1024,
#     ),
#     std=[
#         58.395,
#         57.12,
#         57.375,
#     ],
#     type='SegDataPreProcessor')
# data_root = 'Glomeruli-dataset'
# dataset_type = 'StanfordBackgroundDataset'
# default_hooks = dict(
#     checkpoint=dict(
#         by_epoch=False,
#         filename_tmpl='CE+Dice{}.pth',
#         interval=2000,
#         save_best='mIoU',
#         type='CheckpointHook'))
# default_scope = 'mmseg'
# env_cfg = dict(
#     cudnn_benchmark=True,
#     dist_cfg=dict(backend='nccl'),
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0))
# img_ratios = [
#     0.5,
#     0.75,
#     1.0,
#     1.25,
#     1.5,
#     1.75,
# ]
# load_from = 'pspnet_r50-d8_512x1024_40k_cityscapes_20200605_003338-2966598c.pth'
# log_level = 'INFO'
# log_processor = dict(by_epoch=False)
# metainfo = dict(
#     classes=(
#         'background',
#         'glomeruili',
#     ),
#     palette=[
#         [
#             0,
#             0,
#             0,
#         ],
#         [
#             255,
#             0,
#             0,
#         ],
#     ])
# model = dict(
#     auxiliary_head=dict(
#         align_corners=False,
#         channels=256,
#         concat_input=False,
#         dropout_ratio=0.1,
#         in_channels=1024,
#         in_index=2,
#         loss_decode=[
#             dict(loss_weight=0.4, type='CrossEntropyLoss', use_sigmoid=False),
#             dict(loss_weight=0.2, type='DiceLoss'),
#         ],
#         norm_cfg=dict(requires_grad=True, type='BN'),
#         num_classes=2,
#         num_convs=1,
#         type='FCNHead'),
#     backbone=dict(
#         contract_dilation=True,
#         depth=50,
#         dilations=(
#             1,
#             1,
#             2,
#             4,
#         ),
#         norm_cfg=dict(requires_grad=True, type='BN'),
#         norm_eval=False,
#         num_stages=4,
#         out_indices=(
#             0,
#             1,
#             2,
#             3,
#         ),
#         strides=(
#             1,
#             2,
#             1,
#             1,
#         ),
#         style='pytorch',
#         type='ResNetV1c'),
#     data_preprocessor=dict(
#         bgr_to_rgb=True,
#         mean=[
#             123.675,
#             116.28,
#             103.53,
#         ],
#         pad_val=0,
#         seg_pad_val=255,
#         size=(
#             256,
#             256,
#         ),
#         std=[
#             58.395,
#             57.12,
#             57.375,
#         ],
#         type='SegDataPreProcessor'),
#     decode_head=dict(
#         align_corners=False,
#         channels=512,
#         dropout_ratio=0.1,
#         in_channels=2048,
#         in_index=3,
#         loss_decode=[
#             dict(loss_weight=1.0, type='CrossEntropyLoss', use_sigmoid=False),
#             dict(loss_weight=0.5, type='DiceLoss'),
#         ],
#         norm_cfg=dict(requires_grad=True, type='BN'),
#         num_classes=2,
#         pool_scales=(
#             1,
#             2,
#             3,
#             6,
#         ),
#         type='PSPHead'),
#     pretrained=None,
#     test_cfg=dict(mode='whole'),
#     train_cfg=None,
#     type='EncoderDecoder')
# norm_cfg = dict(requires_grad=True, type='BN')
# optim_wrapper = dict(
#     clip_grad=None,
#     optimizer=dict(lr=0.01, momentum=0.9, type='SGD', weight_decay=0.0005),
#     type='OptimWrapper')
# optimizer = dict(lr=0.01, momentum=0.9, type='SGD', weight_decay=0.0005)
# param_scheduler = [
#     dict(by_epoch=False, end=500, start_factor=0.1, type='LinearLR'),
#     dict(
#         begin=500,
#         by_epoch=False,
#         end=30000,
#         eta_min=0.0001,
#         power=0.9,
#         type='PolyLR'),
# ]
# randomness = dict(seed=0)
# resume = False
# test_cfg = dict(type='TestLoop')
# test_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='splits/val.txt',
#         data_prefix=dict(img_path='images', seg_map_path='masks'),
#         data_root='Glomeruli-dataset',
#         metainfo=dict(
#             classes=(
#                 'background',
#                 'glomeruili',
#             ),
#             palette=[
#                 [
#                     0,
#                     0,
#                     0,
#                 ],
#                 [
#                     255,
#                     0,
#                     0,
#                 ],
#             ]),
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 320,
#                 240,
#             ), type='Resize'),
#             dict(type='LoadAnnotations'),
#             dict(type='PackSegInputs'),
#         ],
#         type='StanfordBackgroundDataset'),
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# test_evaluator = dict(
#     iou_metrics=[
#         'mIoU',
#     ], type='IoUMetric')
# test_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(keep_ratio=True, scale=(
#         320,
#         240,
#     ), type='Resize'),
#     dict(type='LoadAnnotations'),
#     dict(type='PackSegInputs'),
# ]
# train_cfg = dict(max_iters=30000, type='IterBasedTrainLoop', val_interval=500)
# train_dataloader = dict(
#     batch_size=8,
#     dataset=dict(
#         ann_file='splits/train.txt',
#         data_prefix=dict(img_path='images', seg_map_path='masks'),
#         data_root='Glomeruli-dataset',
#         metainfo=dict(
#             classes=(
#                 'background',
#                 'glomeruili',
#             ),
#             palette=[
#                 [
#                     0,
#                     0,
#                     0,
#                 ],
#                 [
#                     255,
#                     0,
#                     0,
#                 ],
#             ]),
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='LoadAnnotations'),
#             dict(
#                 keep_ratio=True,
#                 ratio_range=(
#                     0.5,
#                     2.0,
#                 ),
#                 scale=(
#                     320,
#                     240,
#                 ),
#                 type='RandomResize'),
#             dict(
#                 cat_max_ratio=0.75, crop_size=(
#                     256,
#                     256,
#                 ), type='RandomCrop'),
#             dict(prob=0.5, type='RandomFlip'),
#             dict(type='PackSegInputs'),
#         ],
#         type='StanfordBackgroundDataset'),
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=True, type='InfiniteSampler'))
# train_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='LoadAnnotations'),
#     dict(
#         keep_ratio=True,
#         ratio_range=(
#             0.5,
#             2.0,
#         ),
#         scale=(
#             320,
#             240,
#         ),
#         type='RandomResize'),
#     dict(cat_max_ratio=0.75, crop_size=(
#         256,
#         256,
#     ), type='RandomCrop'),
#     dict(prob=0.5, type='RandomFlip'),
#     dict(type='PackSegInputs'),
# ]
# tta_model = dict(type='SegTTAModel')
# tta_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(
#         transforms=[
#             [
#                 dict(keep_ratio=True, scale_factor=0.5, type='Resize'),
#                 dict(keep_ratio=True, scale_factor=0.75, type='Resize'),
#                 dict(keep_ratio=True, scale_factor=1.0, type='Resize'),
#                 dict(keep_ratio=True, scale_factor=1.25, type='Resize'),
#                 dict(keep_ratio=True, scale_factor=1.5, type='Resize'),
#                 dict(keep_ratio=True, scale_factor=1.75, type='Resize'),
#             ],
#             [
#                 dict(direction='horizontal', prob=0.0, type='RandomFlip'),
#                 dict(direction='horizontal', prob=1.0, type='RandomFlip'),
#             ],
#             [
#                 dict(type='LoadAnnotations'),
#             ],
#             [
#                 dict(type='PackSegInputs'),
#             ],
#         ],
#         type='TestTimeAug'),
# ]
# val_cfg = dict(type='ValLoop')
# val_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='splits/val.txt',
#         data_prefix=dict(img_path='images', seg_map_path='masks'),
#         data_root='Glomeruli-dataset',
#         metainfo=dict(
#             classes=(
#                 'background',
#                 'glomeruili',
#             ),
#             palette=[
#                 [
#                     0,
#                     0,
#                     0,
#                 ],
#                 [
#                     255,
#                     0,
#                     0,
#                 ],
#             ]),
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 320,
#                 240,
#             ), type='Resize'),
#             dict(type='LoadAnnotations'),
#             dict(type='PackSegInputs'),
#         ],
#         type='StanfordBackgroundDataset'),
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# val_evaluator = dict(
#     dataset_meta=dict(
#         classes=(
#             'background',
#             'glomeruili',
#         ),
#         palette=[
#             [
#                 0,
#                 0,
#                 0,
#             ],
#             [
#                 255,
#                 0,
#                 0,
#             ],
#         ]),
#     format_only=False,
#     iou_metrics=[
#         'mIoU',
#         'mDice',
#         'mFscore',
#     ],
#     output_dir='val_metrics',
#     type='IoUMetric')
# vis_backends = [
#     dict(type='LocalVisBackend'),
# ]
# visualizer = dict(
#     name='visualizer',
#     type='SegLocalVisualizer',
#     vis_backends=[
#         dict(type='LocalVisBackend'),
#     ])
# work_dir = './work_dirs/tutorial'
# /home/featurize/work/MMSegmentation_Tutorials-main/20230215/mmsegmentation/mmseg/models/decode_heads/decode_head.py:120: UserWarning: For binary segmentation, we suggest using`out_channels = 1` to define the outputchannels of segmentor, and use `threshold`to convert `seg_logits` into a predictionapplying a threshold
#   warnings.warn('For binary segmentation, we suggest using'
# /home/featurize/work/MMSegmentation_Tutorials-main/20230215/mmsegmentation/mmseg/models/losses/cross_entropy_loss.py:251: UserWarning: Default ``avg_non_ignore`` is False, if you would like to ignore the certain label and average loss over non-ignore labels, which is the same with PyTorch official cross_entropy, set ``avg_non_ignore=True``.
#   'Default ``avg_non_ignore`` is False, if you would like to '
# 05/14 02:42:27 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 05/14 02:42:27 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------

# %% [markdown]
# ## 开始训练
#
# 如果遇到报错`CUDA out of memeory`，重启实例或使用显存更高的实例即可。

# %%
runner.train()
# Out:
# 05/14 02:42:28 - mmengine - WARNING - The prefix is not set in metric class IoUMetric.
# Loads checkpoint by local backend from path: pspnet_r50-d8_512x1024_40k_cityscapes_20200605_003338-2966598c.pth
# The model and loaded state dict do not match exactly
#
# size mismatch for decode_head.conv_seg.weight: copying a param with shape torch.Size([19, 512, 1, 1]) from checkpoint, the shape in current model is torch.Size([2, 512, 1, 1]).
# size mismatch for decode_head.conv_seg.bias: copying a param with shape torch.Size([19]) from checkpoint, the shape in current model is torch.Size([2]).
# size mismatch for auxiliary_head.conv_seg.weight: copying a param with shape torch.Size([19, 256, 1, 1]) from checkpoint, the shape in current model is torch.Size([2, 256, 1, 1]).
# size mismatch for auxiliary_head.conv_seg.bias: copying a param with shape torch.Size([19]) from checkpoint, the shape in current model is torch.Size([2]).
# 05/14 02:42:29 - mmengine - INFO - Load checkpoint from pspnet_r50-d8_512x1024_40k_cityscapes_20200605_003338-2966598c.pth
# 05/14 02:42:29 - mmengine - WARNING - "FileClient" will be deprecated in future. Please use io functions in https://mmengine.readthedocs.io/en/latest/api/fileio.html#file-io
# 05/14 02:42:29 - mmengine - WARNING - "HardDiskBackend" is the alias of "LocalBackend" and the former will be deprecated in future.
# 05/14 02:42:29 - mmengine - INFO - Checkpoints will be saved to /home/featurize/work/MMSegmentation_Tutorials-main/20230215/【D1】Kaggle代码实战-肾小球切片语义分割/work_dirs/tutorial.
# 05/14 02:42:35 - mmengine - INFO - Iter(train) [   10/30000]  lr: 1.1623e-03  eta: 4:29:55  time: 0.5400  data_time: 0.0129  memory: 6137  loss: 0.8443  decode.loss_ce: 0.3966  decode.loss_dice: 0.1785  decode.acc_seg: 97.1767  aux.loss_ce: 0.1907  aux.loss_dice: 0.0785  aux.acc_seg: 97.1767
# 05/14 02:42:38 - mmengine - INFO - Iter(train) [   20/30000]  lr: 1.3427e-03  eta: 3:36:45  time: 0.3276  data_time: 0.0111  memory: 3962  loss: 0.5480  decode.loss_ce: 0.2125  decode.loss_dice: 0.1169  decode.acc_seg: 97.8641  aux.loss_ce: 0.1543  aux.loss_dice: 0.0642  aux.acc_seg: 97.8641
# 05/14 02:49:01 - mmengine - INFO - Iter(val) [450/515]    eta: 0:00:03  time: 0.0543  data_time: 0.0031  memory: 996
# 05/14 02:49:02 - mmengine - INFO - Iter(val) [460/515]    eta: 0:00:03  time: 0.0540  data_time: 0.0029  memory: 996
# 05/14 02:49:03 - mmengine - INFO - Iter(val) [470/515]    eta: 0:00:02  time: 0.0540  data_time: 0.0028  memory: 996
# 05/14 02:49:03 - mmengine - INFO - Iter(val) [480/515]    eta: 0:00:01  time: 0.0640  data_time: 0.0035  memory: 996
# 05/14 02:49:04 - mmengine - INFO - Iter(val) [490/515]    eta: 0:00:01  time: 0.0653  data_time: 0.0044  memory: 996
# 05/14 02:49:04 - mmengine - INFO - Iter(val) [500/515]    eta: 0:00:00  time: 0.0591  data_time: 0.0036  memory: 996
# 05/14 02:49:05 - mmengine - INFO - Iter(val) [510/515]    eta: 0:00:00  time: 0.0587  data_time: 0.0030  memory: 996
# 05/14 02:49:05 - mmengine - INFO - per class results:
# 05/14 02:49:05 - mmengine - INFO -
# +------------+-------+-------+-------+--------+-----------+--------+
# |   Class    |  IoU  |  Acc  |  Dice | Fscore | Precision | Recall |
# +------------+-------+-------+-------+--------+-----------+--------+
# | background |  99.5 | 99.92 | 99.75 | 99.75  |   99.58   | 99.92  |
# | glomeruili | 66.95 | 70.65 |  80.2 |  80.2  |   92.74   | 70.65  |
# +------------+-------+-------+-------+--------+-----------+--------+
# 05/14 02:49:05 - mmengine - INFO - Iter(val) [515/515]    aAcc: 99.5000  mIoU: 83.2200  mAcc: 85.2900  mDice: 89.9800  mFscore: 89.9800  mPrecision: 96.1600  mRecall: 85.2900  data_time: 0.0032  time: 0.0561
# 05/14 02:49:05 - mmengine - INFO - The previous best checkpoint /home/featurize/work/MMSegmentation_Tutorials-main/20230215/【D1】Kaggle代码实战-肾小球切片语义分割/work_dirs/tutorial/best_mIoU_CE+Dice500.pth is removed
# 05/14 02:49:07 - mmengine - INFO - The best checkpoint with 83.2200 mIoU at 1000 iter is saved to best_mIoU_CE+Dice1000.pth.
# 05/14 02:49:10 - mmengine - INFO - Iter(train) [ 1010/30000]  lr: 9.8461e-03  eta: 2:42:53  time: 0.4904  data_time: 0.1674  memory: 3962  loss: 0.0233  decode.loss_ce: 0.0124  decode.loss_dice: 0.0032  decode.acc_seg: 95.6160  aux.loss_ce: 0.0056  aux.loss_dice: 0.0021  aux.acc_seg: 96.4779
# 05/14 02:49:14 - mmengine - INFO - Iter(train) [ 1020/30000]  lr: 9.8431e-03  eta: 2:42:48  time: 0.3318  data_time: 0.0120  memory: 3962  loss: 0.0677  decode.loss_ce: 0.0417  decode.loss_dice: 0.0080  decode.acc_seg: 99.0040  aux.loss_ce: 0.0131  aux.loss_dice: 0.0049  aux.acc_seg: 99.0841
# 05/14 02:49:17 - mmengine - INFO - Iter(train) [ 1030/30000]  lr: 9.8401e-03  eta: 2:42:43  time: 0.3343  data_time: 0.0134  memory: 3962  loss: 0.0339  decode.loss_ce: 0.0173  decode.loss_dice: 0.0052  decode.acc_seg: 99.8887  aux.loss_ce: 0.0082  aux.loss_dice: 0.0031  aux.acc_seg: 99.9647
# 05/14 02:49:20 - mmengine - INFO - Iter(train) [ 1040/30000]  lr: 9.8370e-03  eta: 2:42:39  time: 0.3326  data_time: 0.0120  memory: 3962  loss: 0.0236  decode.loss_ce: 0.0121  decode.loss_dice: 0.0038  decode.acc_seg: 100.0000  aux.loss_ce: 0.0053  aux.loss_dice: 0.0024  aux.acc_seg: 100.0000
# 05/14 02:49:24 - mmengine - INFO - Iter(train) [ 1050/30000]  lr: 9.8340e-03  eta: 2:42:34  time: 0.3317  data_time: 0.0119  memory: 3962  loss: 0.0442  decode.loss_ce: 0.0227  decode.loss_dice: 0.0056  decode.acc_seg: 99.4180  aux.loss_ce: 0.0122  aux.loss_dice: 0.0037  aux.acc_seg: 99.5959
# 05/14 02:49:27 - mmengine - INFO - Iter(train) [ 1060/30000]  lr: 9.8310e-03  eta: 2:42:30  time: 0.3355  data_time: 0.0128  memory: 3962  loss: 0.0488  decode.loss_ce: 0.0278  decode.loss_dice: 0.0065  decode.acc_seg: 97.1562  aux.loss_ce: 0.0112  aux.loss_dice: 0.0034  aux.acc_seg: 97.1736
# 05/14 02:49:30 - mmengine - INFO - Iter(train) [ 1070/30000]  lr: 9.8280e-03  eta: 2:42:26  time: 0.3339  data_time: 0.0131  memory: 3962  loss: 0.0223  decode.loss_ce: 0.0104  decode.loss_dice: 0.0040  decode.acc_seg: 100.0000  aux.loss_ce: 0.0054  aux.loss_dice: 0.0024  aux.acc_seg: 99.9981
# 05/14 02:49:34 - mmengine - INFO - Iter(train) [ 1080/30000]  lr: 9.8249e-03  eta: 2:42:22  time: 0.3347  data_time: 0.0128  memory: 3962  loss: 0.0356  decode.loss_ce: 0.0178  decode.loss_dice: 0.0056  decode.acc_seg: 99.7224  aux.loss_ce: 0.0088  aux.loss_dice: 0.0034  aux.acc_seg: 99.7784
# 05/14 02:49:37 - mmengine - INFO - Iter(train) [ 1090/30000]  lr: 9.8219e-03  eta: 2:42:18  time: 0.3343  data_time: 0.0125  memory: 3962  loss: 0.0421  decode.loss_ce: 0.0214  decode.loss_dice: 0.0055  decode.acc_seg: 100.0000  aux.loss_ce: 0.0118  aux.loss_dice: 0.0034  aux.acc_seg: 99.6755
# 05/14 02:49:40 - mmengine - INFO - Iter(train) [ 1100/30000]  lr: 9.8189e-03  eta: 2:42:14  time: 0.3338  data_time: 0.0123  memory: 3962  loss: 0.0371  decode.loss_ce: 0.0192  decode.loss_dice: 0.0058  decode.acc_seg: 99.6042  aux.loss_ce: 0.0087  aux.loss_dice: 0.0034  aux.acc_seg: 99.5507
# ...
# 05/14 03:56:21 - mmengine - INFO - Iter(train) [11160/30000]  lr: 6.7127e-03  eta: 1:45:26  time: 0.3329  data_time: 0.0118  memory: 3962  loss: 0.0076  decode.loss_ce: 0.0037  decode.loss_dice: 0.0014  decode.acc_seg: 99.4526  aux.loss_ce: 0.0018  aux.loss_dice: 0.0007  aux.acc_seg: 99.3506
# 05/14 03:56:24 - mmengine - INFO - Iter(train) [11170/30000]  lr: 6.7096e-03  eta: 1:45:22  time: 0.3341  data_time: 0.0128  memory: 3962  loss: 0.0108  decode.loss_ce: 0.0053  decode.loss_dice: 0.0017  decode.acc_seg: 99.1182  aux.loss_ce: 0.0026  aux.loss_dice: 0.0011  aux.acc_seg: 99.0281
# 05/14 03:56:27 - mmengine - INFO - Iter(train) [11180/30000]  lr: 6.7064e-03  eta: 1:45:19  time: 0.3312  data_time: 0.0108  memory: 3962  loss: 0.0108  decode.loss_ce: 0.0057  decode.loss_dice: 0.0015  decode.acc_seg: 99.6303  aux.loss_ce: 0.0027  aux.loss_dice: 0.0009  aux.acc_seg: 99.6279
# 05/14 03:56:31 - mmengine - INFO - Iter(train) [11190/30000]  lr: 6.7033e-03  eta: 1:45:15  time: 0.3309  data_time: 0.0107  memory: 3962  loss: 0.0116  decode.loss_ce: 0.0049  decode.loss_dice: 0.0018  decode.acc_seg: 99.8392  aux.loss_ce: 0.0039  aux.loss_dice: 0.0011  aux.acc_seg: 99.8146
# 05/14 03:56:34 - mmengine - INFO - Iter(train) [11200/30000]  lr: 6.7001e-03  eta: 1:45:12  time: 0.3311  data_time: 0.0107  memory: 3962  loss: 0.0084  decode.loss_ce: 0.0037  decode.loss_dice: 0.0017  decode.acc_seg: 99.9172  aux.loss_ce: 0.0017  aux.loss_dice: 0.0012  aux.acc_seg: 99.9226
# 05/14 03:56:37 - mmengine - INFO - Iter(train) [11210/30000]  lr: 6.6969e-03  eta: 1:45:08  time: 0.3309  data_time: 0.0108  memory: 3962  loss: 0.0107  decode.loss_ce: 0.0054  decode.loss_dice: 0.0018  decode.acc_seg: 99.9592  aux.loss_ce: 0.0024  aux.loss_dice: 0.0011  aux.acc_seg: 99.9423
# 05/14 03:56:40 - mmengine - INFO - Iter(train) [11220/30000]  lr: 6.6938e-03  eta: 1:45:05  time: 0.3314  data_time: 0.0109  memory: 3962  loss: 0.0075  decode.loss_ce: 0.0038  decode.loss_dice: 0.0013  decode.acc_seg: 100.0000  aux.loss_ce: 0.0017  aux.loss_dice: 0.0007  aux.acc_seg: 100.0000
# 05/14 03:56:44 - mmengine - INFO - Iter(train) [11230/30000]  lr: 6.6906e-03  eta: 1:45:02  time: 0.3344  data_time: 0.0122  memory: 3962  loss: 0.0106  decode.loss_ce: 0.0047  decode.loss_dice: 0.0020  decode.acc_seg: 99.7165  aux.loss_ce: 0.0026  aux.loss_dice: 0.0012  aux.acc_seg: 99.4764
# 05/14 03:56:47 - mmengine - INFO - Iter(train) [11240/30000]  lr: 6.6875e-03  eta: 1:44:58  time: 0.3348  data_time: 0.0128  memory: 3962  loss: 0.0139  decode.loss_ce: 0.0076  decode.loss_dice: 0.0019  decode.acc_seg: 99.6943  aux.loss_ce: 0.0034  aux.loss_dice: 0.0010  aux.acc_seg: 99.5665
# 05/14 03:56:50 - mmengine - INFO - Iter(train) [11250/30000]  lr: 6.6843e-03  eta: 1:44:55  time: 0.3329  data_time: 0.0115  memory: 3962  loss: 0.0163  decode.loss_ce: 0.0073  decode.loss_dice: 0.0024  decode.acc_seg: 99.3305  aux.loss_ce: 0.0050  aux.loss_dice: 0.0017  aux.acc_seg: 99.2940
# 05/14 03:56:54 - mmengine - INFO - Iter(train) [11260/30000]  lr: 6.6811e-03  eta: 1:44:51  time: 0.3325  data_time: 0.0113  memory: 3962  loss: 0.0182  decode.loss_ce: 0.0097  decode.loss_dice: 0.0025  decode.acc_seg: 98.8879  aux.loss_ce: 0.0048  aux.loss_dice: 0.0013  aux.acc_seg: 99.2300
# 05/14 03:56:57 - mmengine - INFO - Iter(train) [11270/30000]  lr: 6.6780e-03  eta: 1:44:48  time: 0.3318  data_time: 0.0113  memory: 3962  loss: 0.0125  decode.loss_ce: 0.0060  decode.loss_dice: 0.0020  decode.acc_seg: 99.8964  aux.loss_ce: 0.0033  aux.loss_dice: 0.0011  aux.acc_seg: 99.8485
# 05/14 03:57:00 - mmengine - INFO - Iter(train) [11280/30000]  lr: 6.6748e-03  eta: 1:44:45  time: 0.3332  data_time: 0.0114  memory: 3962  loss: 0.0198  decode.loss_ce: 0.0105  decode.loss_dice: 0.0028  decode.acc_seg: 99.9134  aux.loss_ce: 0.0049  aux.loss_dice: 0.0016  aux.acc_seg: 99.9256
# 05/14 03:57:04 - mmengine - INFO - Iter(train) [11290/30000]  lr: 6.6717e-03  eta: 1:44:41  time: 0.3368  data_time: 0.0146  memory: 3962  loss: 0.0152  decode.loss_ce: 0.0083  decode.loss_dice: 0.0025  decode.acc_seg: 99.9184  aux.loss_ce: 0.0032  aux.loss_dice: 0.0013  aux.acc_seg: 99.9201
# 05/14 03:57:07 - mmengine - INFO - Iter(train) [11300/30000]  lr: 6.6685e-03  eta: 1:44:38  time: 0.3347  data_time: 0.0125  memory: 3962  loss: 0.0128  decode.loss_ce: 0.0076  decode.loss_dice: 0.0015  decode.acc_seg: 99.3591  aux.loss_ce: 0.0029  aux.loss_dice: 0.0008  aux.acc_seg: 99.3480
# 05/14 03:57:11 - mmengine - INFO - Iter(train) [11310/30000]  lr: 6.6653e-03  eta: 1:44:34  time: 0.3364  data_time: 0.0132  memory: 3962  loss: 0.0100  decode.loss_ce: 0.0050  decode.loss_dice: 0.0014  decode.acc_seg: 100.0000  aux.loss_ce: 0.0028  aux.loss_dice: 0.0009  aux.acc_seg: 100.0000
# 05/14 03:57:14 - mmengine - INFO - Iter(train) [11320/30000]  lr: 6.6622e-03  eta: 1:44:31  time: 0.3336  data_time: 0.0124  memory: 3962  loss: 0.0117  decode.loss_ce: 0.0067  decode.loss_dice: 0.0018  decode.acc_seg: 99.5251  aux.loss_ce: 0.0022  aux.loss_dice: 0.0010  aux.acc_seg: 99.6714
# 05/14 03:57:17 - mmengine - INFO - Iter(train) [11330/30000]  lr: 6.6590e-03  eta: 1:44:28  time: 0.3308  data_time: 0.0112  memory: 3962  loss: 0.0192  decode.loss_ce: 0.0091  decode.loss_dice: 0.0022  decode.acc_seg: 97.5204  aux.loss_ce: 0.0066  aux.loss_dice: 0.0013  aux.acc_seg: 95.5964
# 05/14 03:57:20 - mmengine - INFO - Iter(train) [11340/30000]  lr: 6.6559e-03  eta: 1:44:24  time: 0.3310  data_time: 0.0109  memory: 3962  loss: 0.0060  decode.loss_ce: 0.0024  decode.loss_dice: 0.0012  decode.acc_seg: 99.9840  aux.loss_ce: 0.0016  aux.loss_dice: 0.0008  aux.acc_seg: 99.9552
# 05/14 03:57:24 - mmengine - INFO - Iter(train) [11350/30000]  lr: 6.6527e-03  eta: 1:44:21  time: 0.3312  data_time: 0.0113  memory: 3962  loss: 0.0143  decode.loss_ce: 0.0062  decode.loss_dice: 0.0022  decode.acc_seg: 99.8497  aux.loss_ce: 0.0044  aux.loss_dice: 0.0015  aux.acc_seg: 99.6953
# 05/14 03:57:27 - mmengine - INFO - Iter(train) [11360/30000]  lr: 6.6495e-03  eta: 1:44:17  time: 0.3316  data_time: 0.0111  memory: 3962  loss: 0.0198  decode.loss_ce: 0.0100  decode.loss_dice: 0.0031  decode.acc_seg: 100.0000  aux.loss_ce: 0.0049  aux.loss_dice: 0.0018  aux.acc_seg: 97.7597
# 05/14 03:57:30 - mmengine - INFO - Iter(train) [11370/30000]  lr: 6.6464e-03  eta: 1:44:14  time: 0.3327  data_time: 0.0119  memory: 3962  loss: 0.0208  decode.loss_ce: 0.0116  decode.loss_dice: 0.0027  decode.acc_seg: 99.9909  aux.loss_ce: 0.0052  aux.loss_dice: 0.0014  aux.acc_seg: 100.0000
# 05/14 03:57:34 - mmengine - INFO - Iter(train) [11380/30000]  lr: 6.6432e-03  eta: 1:44:11  time: 0.3336  data_time: 0.0122  memory: 3962  loss: 0.0176  decode.loss_ce: 0.0088  decode.loss_dice: 0.0024  decode.acc_seg: 99.6200  aux.loss_ce: 0.0049  aux.loss_dice: 0.0014  aux.acc_seg: 98.6056
# 05/14 03:57:37 - mmengine - INFO - Iter(train) [11390/30000]  lr: 6.6400e-03  eta: 1:44:07  time: 0.3335  data_time: 0.0122  memory: 3962  loss: 0.0142  decode.loss_ce: 0.0069  decode.loss_dice: 0.0023  decode.acc_seg: 99.9859  aux.loss_ce: 0.0035  aux.loss_dice: 0.0015  aux.acc_seg: 99.8034
# 05/14 03:57:40 - mmengine - INFO - Iter(train) [11400/30000]  lr: 6.6369e-03  eta: 1:44:04  time: 0.3334  data_time: 0.0120  memory: 3962  loss: 0.0092  decode.loss_ce: 0.0048  decode.loss_dice: 0.0014  decode.acc_seg: 99.6765  aux.loss_ce: 0.0022  aux.loss_dice: 0.0008  aux.acc_seg: 99.6761
# 05/14 03:57:44 - mmengine - INFO - Iter(train) [11410/30000]  lr: 6.6337e-03  eta: 1:44:00  time: 0.3388  data_time: 0.0125  memory: 3962  loss: 0.0082  decode.loss_ce: 0.0037  decode.loss_dice: 0.0016  decode.acc_seg: 99.4956  aux.loss_ce: 0.0019  aux.loss_dice: 0.0011  aux.acc_seg: 99.4540
# 05/14 03:57:47 - mmengine - INFO - Iter(train) [11420/30000]  lr: 6.6306e-03  eta: 1:43:57  time: 0.3343  data_time: 0.0123  memory: 3962  loss: 0.0114  decode.loss_ce: 0.0057  decode.loss_dice: 0.0017  decode.acc_seg: 99.7051  aux.loss_ce: 0.0029  aux.loss_dice: 0.0010  aux.acc_seg: 99.9305
# 05/14 03:57:51 - mmengine - INFO - Iter(train) [11430/30000]  lr: 6.6274e-03  eta: 1:43:54  time: 0.3337  data_time: 0.0125  memory: 3962  loss: 0.0182  decode.loss_ce: 0.0091  decode.loss_dice: 0.0027  decode.acc_seg: 99.8169  aux.loss_ce: 0.0048  aux.loss_dice: 0.0015  aux.acc_seg: 99.8208
# 05/14 03:57:54 - mmengine - INFO - Iter(train) [11440/30000]  lr: 6.6242e-03  eta: 1:43:50  time: 0.3348  data_time: 0.0127  memory: 3962  loss: 0.0125  decode.loss_ce: 0.0066  decode.loss_dice: 0.0018  decode.acc_seg: 99.7671  aux.loss_ce: 0.0030  aux.loss_dice: 0.0010  aux.acc_seg: 99.7560
# 05/14 03:57:57 - mmengine - INFO - Iter(train) [11450/30000]  lr: 6.6211e-03  eta: 1:43:47  time: 0.3319  data_time: 0.0116  memory: 3962  loss: 0.0197  decode.loss_ce: 0.0104  decode.loss_dice: 0.0029  decode.acc_seg: 99.8840  aux.loss_ce: 0.0050  aux.loss_dice: 0.0015  aux.acc_seg: 99.7889
# 05/14 03:58:00 - mmengine - INFO - Iter(train) [11460/30000]  lr: 6.6179e-03  eta: 1:43:43  time: 0.3302  data_time: 0.0116  memory: 3962  loss: 0.0103  decode.loss_ce: 0.0045  decode.loss_dice: 0.0023  decode.acc_seg: 99.8106  aux.loss_ce: 0.0022  aux.loss_dice: 0.0013  aux.acc_seg: 99.7666
# 05/14 03:58:04 - mmengine - INFO - Iter(train) [11470/30000]  lr: 6.6147e-03  eta: 1:43:40  time: 0.3302  data_time: 0.0117  memory: 3962  loss: 0.0102  decode.loss_ce: 0.0052  decode.loss_dice: 0.0018  decode.acc_seg: 99.6490  aux.loss_ce: 0.0023  aux.loss_dice: 0.0010  aux.acc_seg: 99.6536
# 05/14 03:58:07 - mmengine - INFO - Iter(train) [11480/30000]  lr: 6.6116e-03  eta: 1:43:37  time: 0.3302  data_time: 0.0113  memory: 3962  loss: 0.0148  decode.loss_ce: 0.0081  decode.loss_dice: 0.0021  decode.acc_seg: 100.0000  aux.loss_ce: 0.0034  aux.loss_dice: 0.0012  aux.acc_seg: 99.9385
# 05/14 03:58:10 - mmengine - INFO - Iter(train) [11490/30000]  lr: 6.6084e-03  eta: 1:43:33  time: 0.3296  data_time: 0.0116  memory: 3962  loss: 0.0117  decode.loss_ce: 0.0056  decode.loss_dice: 0.0022  decode.acc_seg: 99.6754  aux.loss_ce: 0.0026  aux.loss_dice: 0.0012  aux.acc_seg: 99.6139
# 05/14 03:58:14 - mmengine - INFO - Iter(train) [11500/30000]  lr: 6.6052e-03  eta: 1:43:30  time: 0.3296  data_time: 0.0113  memory: 3962  loss: 0.0143  decode.loss_ce: 0.0079  decode.loss_dice: 0.0022  decode.acc_seg: 99.8710  aux.loss_ce: 0.0031  aux.loss_dice: 0.0011  aux.acc_seg: 99.8361
# 05/14 03:58:14 - mmengine - INFO - Iter(val) [ 10/515]    eta: 0:00:34  time: 0.0691  data_time: 0.0105  memory: 996
# 05/14 03:58:15 - mmengine - INFO - Iter(val) [ 20/515]    eta: 0:00:31  time: 0.0566  data_time: 0.0033  memory: 996
