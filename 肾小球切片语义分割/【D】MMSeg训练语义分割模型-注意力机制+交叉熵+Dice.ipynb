# %% [markdown]
# ## 导入工具包

# %%
import numpy as np
from PIL import Image

import os.path as osp
from tqdm import tqdm

import mmcv
import mmengine
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 数据集图片和标注路径
data_root = 'Glomeruli-dataset'
img_dir = 'images'
ann_dir = 'masks'

# 类别和对应的颜色
classes = ('background', 'glomeruili')
palette = [[128, 128, 128], [151, 189, 8]]

# %% [markdown]
# ## 修改数据集类（指定图像扩展名）

# %% [markdown]
# After downloading the data, we need to implement `load_annotations` function in the new dataset class `StanfordBackgroundDataset`.

# %%
from mmseg.registry import DATASETS
from mmseg.datasets import BaseSegDataset

@DATASETS.register_module()
class StanfordBackgroundDataset(BaseSegDataset):
  METAINFO = dict(classes = classes, palette = palette)
  def __init__(self, **kwargs):
    super().__init__(img_suffix='.png', seg_map_suffix='.png', **kwargs)

# %% [markdown]
# 文档：https://github.com/open-mmlab/mmsegmentation/blob/master/docs/en/tutorials/customize_datasets.md#customize-datasets-by-reorganizing-data

# %% [markdown]
# ## 修改config配置文件

# %%
# 下载 config 文件 和 预训练模型checkpoint权重文件
# !mim download mmsegmentation --config pspnet_r50-d8_4xb2-40k_cityscapes-512x1024 --dest .
# Out:
# processing pspnet_r50-d8_4xb2-40k_cityscapes-512x1024...
# pspnet_r50-d8_512x1024_40k_cityscapes_20200605_003338-2966598c.pth exists in /home/featurize/work/MMSegmentation_Tutorials-main/20230215/【D1】Kaggle代码实战-肾小球切片语义分割
# Successfully dumped pspnet_r50-d8_4xb2-40k_cityscapes-512x1024.py to /home/featurize/work/MMSegmentation_Tutorials-main/20230215/【D1】Kaggle代码实战-肾小球切片语义分割

# %%
from mmengine import Config
cfg = Config.fromfile('./mmsegmentation/configs/pspnet/pspnet_r50-d8_4xb2-40k_cityscapes-512x1024.py')

# %%
cfg.norm_cfg = dict(type='BN', requires_grad=True)  # 只使用GPU时，BN取代SyncBN
cfg.crop_size = (256, 256)
cfg.model.data_preprocessor.size = cfg.crop_size
#backbone基础配置
cfg.model.backbone.norm_cfg = cfg.norm_cfg

import torch
import torch.nn as nn
from mmseg.registry import MODELS

class ChannelAttention(nn.Module):
    def __init__(self, in_planes, ratio=16):
        super(ChannelAttention, self).__init__()
        self.avg_pool = nn.AdaptiveAvgPool2d(1)
        self.max_pool = nn.AdaptiveMaxPool2d(1)

        self.fc1 = nn.Conv2d(in_planes, in_planes // ratio, 1, bias=False)
        self.relu1 = nn.ReLU()
        self.fc2 = nn.Conv2d(in_planes // ratio, in_planes, 1, bias=False)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        avg_out = self.fc2(self.relu1(self.fc1(self.avg_pool(x))))
        max_out = self.fc2(self.relu1(self.fc1(self.max_pool(x))))
        out = avg_out + max_out
        return self.sigmoid(out)


class SpatialAttention(nn.Module):
    def __init__(self, kernel_size=7):
        super(SpatialAttention, self).__init__()

        assert kernel_size in (3, 7), 'kernel size must be 3 or 7'
        padding = 3 if kernel_size == 7 else 1

        self.conv1 = nn.Conv2d(2, 1, kernel_size, padding=padding, bias=False)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        avg_out = torch.mean(x, dim=1, keepdim=True)
        max_out, _ = torch.max(x, dim=1, keepdim=True)
        x = torch.cat([avg_out, max_out], dim=1)
        x = self.conv1(x)
        return self.sigmoid(x)


class CBAM(nn.Module):
    def __init__(self, in_channels, ratio=16, kernel_size=7):
        super(CBAM, self).__init__()
        self.ca = ChannelAttention(in_channels, ratio)
        self.sa = SpatialAttention(kernel_size)

    def forward(self, x):
        x = self.ca(x) * x
        x = self.sa(x) * x
        return x


# 注册手动实现的 CBAM 类
MODELS.register_module(name='CBAM', module=CBAM)

# 添加注意力模块（CBAM）
cfg.model.backbone.update(
    plugins=[
    dict(
        cfg=dict(type='CBAM'),
        stages=(False, False, True, True),  # 第3/4个stage启用（原stage2/3）
        position='after_conv1'
    )
]
)

# 主分割头与辅助分割头基础配置
cfg.model.decode_head.norm_cfg = cfg.norm_cfg
cfg.model.auxiliary_head.norm_cfg = cfg.norm_cfg
# 设置主分割头与辅助分割头的数量
cfg.model.decode_head.num_classes = 2
cfg.model.auxiliary_head.num_classes = 2



# 修改decode_head的损失函数为Dice+交叉熵组合
cfg.model.decode_head.loss_decode = [
    dict(type='CrossEntropyLoss', loss_weight=1.0, use_sigmoid=False),  # 交叉熵
    dict(type='DiceLoss', loss_weight=0.5) 
]

# 修改auxiliary_head的损失函数
cfg.model.auxiliary_head.loss_decode = [
    dict(type='CrossEntropyLoss', loss_weight=0.4, use_sigmoid=False),
    dict(type='DiceLoss', loss_weight=0.2)  
]



# 修改数据集的 type 和 root
cfg.dataset_type = 'StanfordBackgroundDataset'
cfg.data_root = data_root

cfg.train_dataloader.batch_size = 8

cfg.train_pipeline = [
    dict(type='LoadImageFromFile'),
    dict(type='LoadAnnotations'),
    dict(type='RandomResize', scale=(320, 240), ratio_range=(0.5, 2.0), keep_ratio=True),
    dict(type='RandomCrop', crop_size=cfg.crop_size, cat_max_ratio=0.75),
    dict(type='RandomFlip', prob=0.5),
    dict(type='PackSegInputs')
]

cfg.test_pipeline = [
    dict(type='LoadImageFromFile'),
    dict(type='Resize', scale=(320, 240), keep_ratio=True),
    # add loading annotation after ``Resize`` because ground truth
    # does not need to do resize data transform
    dict(type='LoadAnnotations'),
    dict(type='PackSegInputs')
]

cfg.train_dataloader.dataset.type = cfg.dataset_type
cfg.train_dataloader.dataset.data_root = cfg.data_root
cfg.train_dataloader.dataset.data_prefix = dict(img_path=img_dir, seg_map_path=ann_dir)
cfg.train_dataloader.dataset.pipeline = cfg.train_pipeline
cfg.train_dataloader.dataset.ann_file = 'splits/train.txt'

cfg.val_dataloader.dataset.type = cfg.dataset_type
cfg.val_dataloader.dataset.data_root = cfg.data_root
cfg.val_dataloader.dataset.data_prefix = dict(img_path=img_dir, seg_map_path=ann_dir)
cfg.val_dataloader.dataset.pipeline = cfg.test_pipeline
cfg.val_dataloader.dataset.ann_file = 'splits/val.txt'

cfg.test_dataloader = cfg.val_dataloader

# 验证 Evaluator
# val_evaluator = dict(type='IoUMetric', iou_metrics=['mIoU', 'mDice', 'mFscore'])
val_evaluator = dict(
    type='IoUMetric',
    iou_metrics=['mIoU', 'mDice', 'mFscore'],
    output_dir='val_metrics',  # 单独保存验证结果
    format_only=False,
    print_results=True  # 强制打印所有结果
)

# ------------------ 新增数据集元信息 ------------------
cfg.metainfo = {
    'classes': ('background', 'glomeruili'),  # 必须与您的标注类别一致
    'palette': [[0, 0, 0], [255, 0, 0]]     # 颜色配置（可选）
}

# ------------------ 修改评估器配置 ------------------
cfg.val_evaluator = dict(
    type='IoUMetric',
    iou_metrics=['mIoU', 'mDice', 'mFscore'],  # 明确指定所有指标
    output_dir='val_metrics',                  # 评估结果保存路径
    format_only=False,
    # 关键：注入数据集类别信息
    dataset_meta=cfg.metainfo
)

# ------------------ 将metainfo注入所有数据集 ------------------
for ds_key in ['train_dataloader', 'val_dataloader', 'test_dataloader']:
    cfg[ds_key]['dataset']['metainfo'] = cfg.metainfo

# 测试 Evaluator
test_evaluator = val_evaluator

# 载入预训练模型权重
cfg.load_from = 'pspnet_r50-d8_512x1024_40k_cityscapes_20200605_003338-2966598c.pth'

# 工作目录
cfg.work_dir = './work_dirs/tutorial'

cfg.default_hooks = dict(
    checkpoint=dict(
        type='CheckpointHook',
        interval = 400 ,
        by_epoch=False,
        filename_tmpl='CE+Dice+CBAM{}.pth',  # 文件名模板（{} 会被替换为 epoch 或 iter）
        save_best='mIoU'
    )
)


# 训练总迭代次数
cfg.train_cfg.max_iters = 30000  

# 验证频率 (每N次迭代)
cfg.train_cfg.val_interval = 400  # 约每2个epoch验证一次

# 日志记录频率 
#cfg.default_hooks.logger.interval = 50  # 每50iter记录一次

# 模型保存频率
#cfg.default_hooks.checkpoint.interval = 800  # 每800iter保存一次

# 随机数种子
cfg['randomness'] = dict(seed=0)

# 如果遇到内存问题
cfg.train_dataloader.drop_last = True  # 丢弃最后不完整的batch

# %%
from mmseg.apis import init_model
model = init_model(cfg, device='cuda')

# 打印评估器配置
print("当前评估器配置：", cfg.val_evaluator)
# 应输出包含 'mDice' 和 'mFscore' 的配置
# Out:
# /home/featurize/work/MMSegmentation_Tutorials-main/20230215/mmsegmentation/mmsegmentation/mmseg/models/decode_heads/decode_head.py:120: UserWarning: For binary segmentation, we suggest using`out_channels = 1` to define the outputchannels of segmentor, and use `threshold`to convert `seg_logits` into a predictionapplying a threshold
#   warnings.warn('For binary segmentation, we suggest using'
# /home/featurize/work/MMSegmentation_Tutorials-main/20230215/mmsegmentation/mmsegmentation/mmseg/models/losses/cross_entropy_loss.py:251: UserWarning: Default ``avg_non_ignore`` is False, if you would like to ignore the certain label and average loss over non-ignore labels, which is the same with PyTorch official cross_entropy, set ``avg_non_ignore=True``.
#   'Default ``avg_non_ignore`` is False, if you would like to '
# 当前评估器配置： {'type': 'IoUMetric', 'iou_metrics': ['mIoU', 'mDice', 'mFscore'], 'output_dir': 'val_metrics', 'format_only': False, 'dataset_meta': {'classes': ('background', 'glomeruili'), 'palette': [[0, 0, 0], [255, 0, 0]]}}

# %%
#from mmengine.runner import Runner
#runner = Runner.from_cfg(cfg)
#print("验证集类别信息：", runner.val_dataloader.dataset.metainfo)
# 应输出：{'classes': ['background', 'glomeruli'], ...}

# %% [markdown]
# ## 查看完整config配置文件

# %%
print(cfg.pretty_text)
# Out:
# crop_size = (
#     256,
#     256,
# )
# data_preprocessor = dict(
#     bgr_to_rgb=True,
#     mean=[
#         123.675,
#         116.28,
#         103.53,
#     ],
#     pad_val=0,
#     seg_pad_val=255,
#     size=(
#         512,
#         1024,
#     ),
#     std=[
#         58.395,
#         57.12,
#         57.375,
#     ],
#     type='SegDataPreProcessor')
# data_root = 'Glomeruli-dataset'
# dataset_type = 'StanfordBackgroundDataset'
# default_hooks = dict(
#     checkpoint=dict(by_epoch=False, interval=800, type='CheckpointHook'),
#     logger=dict(interval=50, log_metric_by_epoch=False, type='LoggerHook'),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     timer=dict(type='IterTimerHook'),
#     visualization=dict(type='SegVisualizationHook'))
# default_scope = 'mmseg'
# env_cfg = dict(
#     cudnn_benchmark=True,
#     dist_cfg=dict(backend='nccl'),
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0))
# img_ratios = [
#     0.5,
#     0.75,
#     1.0,
#     1.25,
#     1.5,
#     1.75,
# ]
# load_from = 'pspnet_r50-d8_512x1024_40k_cityscapes_20200605_003338-2966598c.pth'
# log_level = 'INFO'
# log_processor = dict(by_epoch=False)
# metainfo = dict(
#     classes=(
#         'background',
#         'glomeruili',
#     ),
#     palette=[
#         [
#             0,
#             0,
#             0,
#         ],
#         [
#             255,
#             0,
#             0,
#         ],
#     ])
# model = dict(
#     auxiliary_head=dict(
#         align_corners=False,
#         channels=256,
#         concat_input=False,
#         dropout_ratio=0.1,
#         in_channels=1024,
#         in_index=2,
#         loss_decode=[
#             dict(loss_weight=0.4, type='CrossEntropyLoss', use_sigmoid=False),
#             dict(loss_weight=0.2, type='DiceLoss'),
#         ],
#         norm_cfg=dict(requires_grad=True, type='BN'),
#         num_classes=2,
#         num_convs=1,
#         type='FCNHead'),
#     backbone=dict(
#         contract_dilation=True,
#         depth=50,
#         dilations=(
#             1,
#             1,
#             2,
#             4,
#         ),
#         norm_cfg=dict(requires_grad=True, type='BN'),
#         norm_eval=False,
#         num_stages=4,
#         out_indices=(
#             0,
#             1,
#             2,
#             3,
#         ),
#         plugins=[
#             dict(
#                 cfg=dict(type='CBAM'),
#                 position='after_conv1',
#                 stages=(
#                     False,
#                     False,
#                     True,
#                     True,
#                 )),
#         ],
#         strides=(
#             1,
#             2,
#             1,
#             1,
#         ),
#         style='pytorch',
#         type='ResNetV1c'),
#     data_preprocessor=dict(
#         bgr_to_rgb=True,
#         mean=[
#             123.675,
#             116.28,
#             103.53,
#         ],
#         pad_val=0,
#         seg_pad_val=255,
#         size=(
#             256,
#             256,
#         ),
#         std=[
#             58.395,
#             57.12,
#             57.375,
#         ],
#         type='SegDataPreProcessor'),
#     decode_head=dict(
#         align_corners=False,
#         channels=512,
#         dropout_ratio=0.1,
#         in_channels=2048,
#         in_index=3,
#         loss_decode=[
#             dict(loss_weight=1.0, type='CrossEntropyLoss', use_sigmoid=False),
#             dict(loss_weight=0.5, type='DiceLoss'),
#         ],
#         norm_cfg=dict(requires_grad=True, type='BN'),
#         num_classes=2,
#         pool_scales=(
#             1,
#             2,
#             3,
#             6,
#         ),
#         type='PSPHead'),
#     pretrained=None,
#     test_cfg=dict(mode='whole'),
#     train_cfg=None,
#     type='EncoderDecoder')
# norm_cfg = dict(requires_grad=True, type='BN')
# optim_wrapper = dict(
#     clip_grad=None,
#     optimizer=dict(lr=0.01, momentum=0.9, type='SGD', weight_decay=0.0005),
#     type='OptimWrapper')
# optimizer = dict(lr=0.01, momentum=0.9, type='SGD', weight_decay=0.0005)
# param_scheduler = [
#     dict(
#         begin=0,
#         by_epoch=False,
#         end=40000,
#         eta_min=0.0001,
#         power=0.9,
#         type='PolyLR'),
# ]
# randomness = dict(seed=0)
# resume = False
# test_cfg = dict(type='TestLoop')
# test_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='splits/val.txt',
#         data_prefix=dict(img_path='images', seg_map_path='masks'),
#         data_root='Glomeruli-dataset',
#         metainfo=dict(
#             classes=(
#                 'background',
#                 'glomeruili',
#             ),
#             palette=[
#                 [
#                     0,
#                     0,
#                     0,
#                 ],
#                 [
#                     255,
#                     0,
#                     0,
#                 ],
#             ]),
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 320,
#                 240,
#             ), type='Resize'),
#             dict(type='LoadAnnotations'),
#             dict(type='PackSegInputs'),
#         ],
#         type='StanfordBackgroundDataset'),
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# test_evaluator = dict(
#     iou_metrics=[
#         'mIoU',
#     ], type='IoUMetric')
# test_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(keep_ratio=True, scale=(
#         320,
#         240,
#     ), type='Resize'),
#     dict(type='LoadAnnotations'),
#     dict(type='PackSegInputs'),
# ]
# train_cfg = dict(max_iters=24000, type='IterBasedTrainLoop', val_interval=400)
# train_dataloader = dict(
#     batch_size=8,
#     dataset=dict(
#         ann_file='splits/train.txt',
#         data_prefix=dict(img_path='images', seg_map_path='masks'),
#         data_root='Glomeruli-dataset',
#         metainfo=dict(
#             classes=(
#                 'background',
#                 'glomeruili',
#             ),
#             palette=[
#                 [
#                     0,
#                     0,
#                     0,
#                 ],
#                 [
#                     255,
#                     0,
#                     0,
#                 ],
#             ]),
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='LoadAnnotations'),
#             dict(
#                 keep_ratio=True,
#                 ratio_range=(
#                     0.5,
#                     2.0,
#                 ),
#                 scale=(
#                     320,
#                     240,
#                 ),
#                 type='RandomResize'),
#             dict(
#                 cat_max_ratio=0.75, crop_size=(
#                     256,
#                     256,
#                 ), type='RandomCrop'),
#             dict(prob=0.5, type='RandomFlip'),
#             dict(type='PackSegInputs'),
#         ],
#         type='StanfordBackgroundDataset'),
#     drop_last=True,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=True, type='InfiniteSampler'))
# train_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='LoadAnnotations'),
#     dict(
#         keep_ratio=True,
#         ratio_range=(
#             0.5,
#             2.0,
#         ),
#         scale=(
#             320,
#             240,
#         ),
#         type='RandomResize'),
#     dict(cat_max_ratio=0.75, crop_size=(
#         256,
#         256,
#     ), type='RandomCrop'),
#     dict(prob=0.5, type='RandomFlip'),
#     dict(type='PackSegInputs'),
# ]
# tta_model = dict(type='SegTTAModel')
# tta_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(
#         transforms=[
#             [
#                 dict(keep_ratio=True, scale_factor=0.5, type='Resize'),
#                 dict(keep_ratio=True, scale_factor=0.75, type='Resize'),
#                 dict(keep_ratio=True, scale_factor=1.0, type='Resize'),
#                 dict(keep_ratio=True, scale_factor=1.25, type='Resize'),
#                 dict(keep_ratio=True, scale_factor=1.5, type='Resize'),
#                 dict(keep_ratio=True, scale_factor=1.75, type='Resize'),
#             ],
#             [
#                 dict(direction='horizontal', prob=0.0, type='RandomFlip'),
#                 dict(direction='horizontal', prob=1.0, type='RandomFlip'),
#             ],
#             [
#                 dict(type='LoadAnnotations'),
#             ],
#             [
#                 dict(type='PackSegInputs'),
#             ],
#         ],
#         type='TestTimeAug'),
# ]
# val_cfg = dict(type='ValLoop')
# val_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='splits/val.txt',
#         data_prefix=dict(img_path='images', seg_map_path='masks'),
#         data_root='Glomeruli-dataset',
#         metainfo=dict(
#             classes=(
#                 'background',
#                 'glomeruili',
#             ),
#             palette=[
#                 [
#                     0,
#                     0,
#                     0,
#                 ],
#                 [
#                     255,
#                     0,
#                     0,
#                 ],
#             ]),
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 320,
#                 240,
#             ), type='Resize'),
#             dict(type='LoadAnnotations'),
#             dict(type='PackSegInputs'),
#         ],
#         type='StanfordBackgroundDataset'),
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# val_evaluator = dict(
#     dataset_meta=dict(
#         classes=(
#             'background',
#             'glomeruili',
#         ),
#         palette=[
#             [
#                 0,
#                 0,
#                 0,
#             ],
#             [
#                 255,
#                 0,
#                 0,
#             ],
#         ]),
#     format_only=False,
#     iou_metrics=[
#         'mIoU',
#         'mDice',
#         'mFscore',
#     ],
#     output_dir='val_metrics',
#     type='IoUMetric')
# vis_backends = [
#     dict(type='LocalVisBackend'),
# ]
# visualizer = dict(
#     name='visualizer',
#     type='SegLocalVisualizer',
#     vis_backends=[
#         dict(type='LocalVisBackend'),
#     ])
# work_dir = './work_dirs/tutorial'

# %% [markdown]
# ## 保存config配置文件

# %%
cfg.dump('new_cfg4.py')

# %% [markdown]
# ## 准备训练

# %%
from mmengine.runner import Runner
from mmseg.utils import register_all_modules

# register all modules in mmseg into the registries
# do not init the default scope here because it will be init in the runner
register_all_modules(init_default_scope=False)
runner = Runner.from_cfg(cfg)
# Out:
# 04/28 18:18:28 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.7.10 (default, Jun  4 2021, 14:48:32) [GCC 7.5.0]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 0
#     GPU 0: Tesla V100-SXM2-16GB
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 11.2, V11.2.152
#     GCC: gcc (Ubuntu 9.3.0-17ubuntu1~20.04) 9.3.0
#     PyTorch: 1.10.1+cu113
#     PyTorch compiling details: PyTorch built with:
#   - GCC 7.3
#   - C++ Version: 201402
#   - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.2.3 (Git Hash 7336ca9f055cf1bfa13efb658fe15dc9b41f0740)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX512
#   - CUDA Runtime 11.3
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86
#   - CuDNN 8.2
#   - Magma 2.5.2
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.3, CUDNN_VERSION=8.2.0, CXX_COMPILER=/opt/rh/devtoolset-7/root/usr/bin/c++, CXX_FLAGS= -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -fopenmp -DNDEBUG -DUSE_KINETO -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -DEDGE_PROFILER_USE_KINETO -O2 -fPIC -Wno-narrowing -Wall -Wextra -Werror=return-type -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wno-sign-compare -Wno-unused-parameter -Wno-unused-variable -Wno-unused-function -Wno-unused-result -Wno-unused-local-typedefs -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_VERSION=1.10.1, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=ON, USE_NNPACK=ON, USE_OPENMP=ON,
#
#     TorchVision: 0.11.2+cu113
#     OpenCV: 4.5.4
#     MMEngine: 0.10.7
#
# Runtime environment:
#     cudnn_benchmark: True
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: 0
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 04/28 18:18:28 - mmengine - INFO - Config:
# crop_size = (
#     256,
#     256,
# )
# data_preprocessor = dict(
#     bgr_to_rgb=True,
#     mean=[
#         123.675,
#         116.28,
#         103.53,
#     ],
#     pad_val=0,
#     seg_pad_val=255,
#     size=(
#         512,
#         1024,
#     ),
#     std=[
#         58.395,
#         57.12,
#         57.375,
#     ],
#     type='SegDataPreProcessor')
# data_root = 'Glomeruli-dataset'
# dataset_type = 'StanfordBackgroundDataset'
# default_hooks = dict(
#     checkpoint=dict(by_epoch=False, interval=800, type='CheckpointHook'),
#     logger=dict(interval=50, log_metric_by_epoch=False, type='LoggerHook'),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     timer=dict(type='IterTimerHook'),
#     visualization=dict(type='SegVisualizationHook'))
# default_scope = 'mmseg'
# env_cfg = dict(
#     cudnn_benchmark=True,
#     dist_cfg=dict(backend='nccl'),
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0))
# img_ratios = [
#     0.5,
#     0.75,
#     1.0,
#     1.25,
#     1.5,
#     1.75,
# ]
# load_from = 'pspnet_r50-d8_512x1024_40k_cityscapes_20200605_003338-2966598c.pth'
# log_level = 'INFO'
# log_processor = dict(by_epoch=False)
# metainfo = dict(
#     classes=(
#         'background',
#         'glomeruili',
#     ),
#     palette=[
#         [
#             0,
#             0,
#             0,
#         ],
#         [
#             255,
#             0,
#             0,
#         ],
#     ])
# model = dict(
#     auxiliary_head=dict(
#         align_corners=False,
#         channels=256,
#         concat_input=False,
#         dropout_ratio=0.1,
#         in_channels=1024,
#         in_index=2,
#         loss_decode=[
#             dict(loss_weight=0.4, type='CrossEntropyLoss', use_sigmoid=False),
#             dict(loss_weight=0.2, type='DiceLoss'),
#         ],
#         norm_cfg=dict(requires_grad=True, type='BN'),
#         num_classes=2,
#         num_convs=1,
#         type='FCNHead'),
#     backbone=dict(
#         contract_dilation=True,
#         depth=50,
#         dilations=(
#             1,
#             1,
#             2,
#             4,
#         ),
#         norm_cfg=dict(requires_grad=True, type='BN'),
#         norm_eval=False,
#         num_stages=4,
#         out_indices=(
#             0,
#             1,
#             2,
#             3,
#         ),
#         plugins=[
#             dict(
#                 cfg=dict(type='CBAM'),
#                 position='after_conv1',
#                 stages=(
#                     False,
#                     False,
#                     True,
#                     True,
#                 )),
#         ],
#         strides=(
#             1,
#             2,
#             1,
#             1,
#         ),
#         style='pytorch',
#         type='ResNetV1c'),
#     data_preprocessor=dict(
#         bgr_to_rgb=True,
#         mean=[
#             123.675,
#             116.28,
#             103.53,
#         ],
#         pad_val=0,
#         seg_pad_val=255,
#         size=(
#             256,
#             256,
#         ),
#         std=[
#             58.395,
#             57.12,
#             57.375,
#         ],
#         type='SegDataPreProcessor'),
#     decode_head=dict(
#         align_corners=False,
#         channels=512,
#         dropout_ratio=0.1,
#         in_channels=2048,
#         in_index=3,
#         loss_decode=[
#             dict(loss_weight=1.0, type='CrossEntropyLoss', use_sigmoid=False),
#             dict(loss_weight=0.5, type='DiceLoss'),
#         ],
#         norm_cfg=dict(requires_grad=True, type='BN'),
#         num_classes=2,
#         pool_scales=(
#             1,
#             2,
#             3,
#             6,
#         ),
#         type='PSPHead'),
#     pretrained=None,
#     test_cfg=dict(mode='whole'),
#     train_cfg=None,
#     type='EncoderDecoder')
# norm_cfg = dict(requires_grad=True, type='BN')
# optim_wrapper = dict(
#     clip_grad=None,
#     optimizer=dict(lr=0.01, momentum=0.9, type='SGD', weight_decay=0.0005),
#     type='OptimWrapper')
# optimizer = dict(lr=0.01, momentum=0.9, type='SGD', weight_decay=0.0005)
# param_scheduler = [
#     dict(
#         begin=0,
#         by_epoch=False,
#         end=40000,
#         eta_min=0.0001,
#         power=0.9,
#         type='PolyLR'),
# ]
# randomness = dict(seed=0)
# resume = False
# test_cfg = dict(type='TestLoop')
# test_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='splits/val.txt',
#         data_prefix=dict(img_path='images', seg_map_path='masks'),
#         data_root='Glomeruli-dataset',
#         metainfo=dict(
#             classes=(
#                 'background',
#                 'glomeruili',
#             ),
#             palette=[
#                 [
#                     0,
#                     0,
#                     0,
#                 ],
#                 [
#                     255,
#                     0,
#                     0,
#                 ],
#             ]),
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 320,
#                 240,
#             ), type='Resize'),
#             dict(type='LoadAnnotations'),
#             dict(type='PackSegInputs'),
#         ],
#         type='StanfordBackgroundDataset'),
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# test_evaluator = dict(
#     iou_metrics=[
#         'mIoU',
#     ], type='IoUMetric')
# test_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(keep_ratio=True, scale=(
#         320,
#         240,
#     ), type='Resize'),
#     dict(type='LoadAnnotations'),
#     dict(type='PackSegInputs'),
# ]
# train_cfg = dict(max_iters=24000, type='IterBasedTrainLoop', val_interval=400)
# train_dataloader = dict(
#     batch_size=8,
#     dataset=dict(
#         ann_file='splits/train.txt',
#         data_prefix=dict(img_path='images', seg_map_path='masks'),
#         data_root='Glomeruli-dataset',
#         metainfo=dict(
#             classes=(
#                 'background',
#                 'glomeruili',
#             ),
#             palette=[
#                 [
#                     0,
#                     0,
#                     0,
#                 ],
#                 [
#                     255,
#                     0,
#                     0,
#                 ],
#             ]),
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='LoadAnnotations'),
#             dict(
#                 keep_ratio=True,
#                 ratio_range=(
#                     0.5,
#                     2.0,
#                 ),
#                 scale=(
#                     320,
#                     240,
#                 ),
#                 type='RandomResize'),
#             dict(
#                 cat_max_ratio=0.75, crop_size=(
#                     256,
#                     256,
#                 ), type='RandomCrop'),
#             dict(prob=0.5, type='RandomFlip'),
#             dict(type='PackSegInputs'),
#         ],
#         type='StanfordBackgroundDataset'),
#     drop_last=True,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=True, type='InfiniteSampler'))
# train_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='LoadAnnotations'),
#     dict(
#         keep_ratio=True,
#         ratio_range=(
#             0.5,
#             2.0,
#         ),
#         scale=(
#             320,
#             240,
#         ),
#         type='RandomResize'),
#     dict(cat_max_ratio=0.75, crop_size=(
#         256,
#         256,
#     ), type='RandomCrop'),
#     dict(prob=0.5, type='RandomFlip'),
#     dict(type='PackSegInputs'),
# ]
# tta_model = dict(type='SegTTAModel')
# tta_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(
#         transforms=[
#             [
#                 dict(keep_ratio=True, scale_factor=0.5, type='Resize'),
#                 dict(keep_ratio=True, scale_factor=0.75, type='Resize'),
#                 dict(keep_ratio=True, scale_factor=1.0, type='Resize'),
#                 dict(keep_ratio=True, scale_factor=1.25, type='Resize'),
#                 dict(keep_ratio=True, scale_factor=1.5, type='Resize'),
#                 dict(keep_ratio=True, scale_factor=1.75, type='Resize'),
#             ],
#             [
#                 dict(direction='horizontal', prob=0.0, type='RandomFlip'),
#                 dict(direction='horizontal', prob=1.0, type='RandomFlip'),
#             ],
#             [
#                 dict(type='LoadAnnotations'),
#             ],
#             [
#                 dict(type='PackSegInputs'),
#             ],
#         ],
#         type='TestTimeAug'),
# ]
# val_cfg = dict(type='ValLoop')
# val_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='splits/val.txt',
#         data_prefix=dict(img_path='images', seg_map_path='masks'),
#         data_root='Glomeruli-dataset',
#         metainfo=dict(
#             classes=(
#                 'background',
#                 'glomeruili',
#             ),
#             palette=[
#                 [
#                     0,
#                     0,
#                     0,
#                 ],
#                 [
#                     255,
#                     0,
#                     0,
#                 ],
#             ]),
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 320,
#                 240,
#             ), type='Resize'),
#             dict(type='LoadAnnotations'),
#             dict(type='PackSegInputs'),
#         ],
#         type='StanfordBackgroundDataset'),
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# val_evaluator = dict(
#     dataset_meta=dict(
#         classes=(
#             'background',
#             'glomeruili',
#         ),
#         palette=[
#             [
#                 0,
#                 0,
#                 0,
#             ],
#             [
#                 255,
#                 0,
#                 0,
#             ],
#         ]),
#     format_only=False,
#     iou_metrics=[
#         'mIoU',
#         'mDice',
#         'mFscore',
#     ],
#     output_dir='val_metrics',
#     type='IoUMetric')
# vis_backends = [
#     dict(type='LocalVisBackend'),
# ]
# visualizer = dict(
#     name='visualizer',
#     type='SegLocalVisualizer',
#     vis_backends=[
#         dict(type='LocalVisBackend'),
#     ])
# work_dir = './work_dirs/tutorial'
# /home/featurize/work/MMSegmentation_Tutorials-main/20230215/mmsegmentation/mmsegmentation/mmseg/models/decode_heads/decode_head.py:120: UserWarning: For binary segmentation, we suggest using`out_channels = 1` to define the outputchannels of segmentor, and use `threshold`to convert `seg_logits` into a predictionapplying a threshold
#   warnings.warn('For binary segmentation, we suggest using'
# /home/featurize/work/MMSegmentation_Tutorials-main/20230215/mmsegmentation/mmsegmentation/mmseg/models/losses/cross_entropy_loss.py:251: UserWarning: Default ``avg_non_ignore`` is False, if you would like to ignore the certain label and average loss over non-ignore labels, which is the same with PyTorch official cross_entropy, set ``avg_non_ignore=True``.
#   'Default ``avg_non_ignore`` is False, if you would like to '
# 04/28 18:18:29 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 04/28 18:18:29 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SegVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SegVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# /home/featurize/work/MMSegmentation_Tutorials-main/20230215/mmsegmentation/mmsegmentation/mmseg/engine/hooks/visualization_hook.py:60: UserWarning: The draw is False, it means that the hook for visualization will not take effect. The results will NOT be visualized or stored.
#   warnings.warn('The draw is False, it means that the '

# %% [markdown]
# ## 开始训练
#
# 如果遇到报错`CUDA out of memeory`，重启实例或使用显存更高的实例即可。

# %%
runner.train()
# Out:
# 04/28 18:18:31 - mmengine - WARNING - The prefix is not set in metric class IoUMetric.
# Loads checkpoint by local backend from path: pspnet_r50-d8_512x1024_40k_cityscapes_20200605_003338-2966598c.pth
# The model and loaded state dict do not match exactly
#
# size mismatch for decode_head.conv_seg.weight: copying a param with shape torch.Size([19, 512, 1, 1]) from checkpoint, the shape in current model is torch.Size([2, 512, 1, 1]).
# size mismatch for decode_head.conv_seg.bias: copying a param with shape torch.Size([19]) from checkpoint, the shape in current model is torch.Size([2]).
# size mismatch for auxiliary_head.conv_seg.weight: copying a param with shape torch.Size([19, 256, 1, 1]) from checkpoint, the shape in current model is torch.Size([2, 256, 1, 1]).
# size mismatch for auxiliary_head.conv_seg.bias: copying a param with shape torch.Size([19]) from checkpoint, the shape in current model is torch.Size([2]).
# missing keys in source state_dict: backbone.layer3.0.cbam.ca.fc1.weight, backbone.layer3.0.cbam.ca.fc2.weight, backbone.layer3.0.cbam.sa.conv1.weight, backbone.layer3.1.cbam.ca.fc1.weight, backbone.layer3.1.cbam.ca.fc2.weight, backbone.layer3.1.cbam.sa.conv1.weight, backbone.layer3.2.cbam.ca.fc1.weight, backbone.layer3.2.cbam.ca.fc2.weight, backbone.layer3.2.cbam.sa.conv1.weight, backbone.layer3.3.cbam.ca.fc1.weight, backbone.layer3.3.cbam.ca.fc2.weight, backbone.layer3.3.cbam.sa.conv1.weight, backbone.layer3.4.cbam.ca.fc1.weight, backbone.layer3.4.cbam.ca.fc2.weight, backbone.layer3.4.cbam.sa.conv1.weight, backbone.layer3.5.cbam.ca.fc1.weight, backbone.layer3.5.cbam.ca.fc2.weight, backbone.layer3.5.cbam.sa.conv1.weight, backbone.layer4.0.cbam.ca.fc1.weight, backbone.layer4.0.cbam.ca.fc2.weight, backbone.layer4.0.cbam.sa.conv1.weight, backbone.layer4.1.cbam.ca.fc1.weight, backbone.layer4.1.cbam.ca.fc2.weight, backbone.layer4.1.cbam.sa.conv1.weight, backbone.layer4.2.cbam.ca.fc1.weight, backbone.layer4.2.cbam.ca.fc2.weight, backbone.layer4.2.cbam.sa.conv1.weight
#
# 04/28 18:18:32 - mmengine - INFO - Load checkpoint from pspnet_r50-d8_512x1024_40k_cityscapes_20200605_003338-2966598c.pth
# 04/28 18:18:32 - mmengine - WARNING - "FileClient" will be deprecated in future. Please use io functions in https://mmengine.readthedocs.io/en/latest/api/fileio.html#file-io
# 04/28 18:18:32 - mmengine - WARNING - "HardDiskBackend" is the alias of "LocalBackend" and the former will be deprecated in future.
# 04/28 18:18:32 - mmengine - INFO - Checkpoints will be saved to /home/featurize/work/MMSegmentation_Tutorials-main/20230215/【D1】Kaggle代码实战-肾小球切片语义分割/work_dirs/tutorial.
# 04/28 18:18:45 - mmengine - INFO - Iter(train) [   50/24000]  lr: 9.9891e-03  eta: 1:40:56  time: 0.2141  data_time: 0.0084  memory: 6418  loss: 0.1727  decode.loss_ce: 0.0649  decode.loss_dice: 0.0571  decode.acc_seg: 99.7613  aux.loss_ce: 0.0266  aux.loss_dice: 0.0241  aux.acc_seg: 99.7613
# 04/28 18:18:55 - mmengine - INFO - Iter(train) [  100/24000]  lr: 9.9779e-03  eta: 1:33:32  time: 0.2171  data_time: 0.0106  memory: 3906  loss: 0.1292  decode.loss_ce: 0.0447  decode.loss_dice: 0.0426  decode.acc_seg: 97.8993  aux.loss_ce: 0.0226  aux.loss_dice: 0.0193  aux.acc_seg: 97.8993
# 04/28 18:19:06 - mmengine - INFO - Iter(train) [  150/24000]  lr: 9.9668e-03  eta: 1:31:17  time: 0.2214  data_time: 0.0128  memory: 3906  loss: 0.1195  decode.loss_ce: 0.0515  decode.loss_dice: 0.0282  decode.acc_seg: 97.9522  aux.loss_ce: 0.0230  aux.loss_dice: 0.0168  aux.acc_seg: 97.7285
# 04/28 18:19:17 - mmengine - INFO - Iter(train) [  200/24000]  lr: 9.9557e-03  eta: 1:30:02  time: 0.2163  data_time: 0.0087  memory: 3906  loss: 0.0898  decode.loss_ce: 0.0404  decode.loss_dice: 0.0176  decode.acc_seg: 98.7945  aux.loss_ce: 0.0171  aux.loss_dice: 0.0147  aux.acc_seg: 98.6927
# 04/28 18:19:28 - mmengine - INFO - Iter(train) [  250/24000]  lr: 9.9445e-03  eta: 1:29:05  time: 0.2148  data_time: 0.0088  memory: 3906  loss: 0.0847  decode.loss_ce: 0.0318  decode.loss_dice: 0.0207  decode.acc_seg: 99.7821  aux.loss_ce: 0.0133  aux.loss_dice: 0.0190  aux.acc_seg: 99.1965
# 04/28 18:19:30 - mmengine - INFO - Exp name: pspnet_r50-d8_4xb2-40k_cityscapes-512x1024_20250428
- mmengine - INFO - Iter(val) [250/515]    eta: 0:00:14  time: 0.0501  data_time: 0.0023  memory: 999
# 04/28 18:28:04 - mmengine - INFO - Iter(val) [300/515]    eta: 0:00:11  time: 0.0504  data_time: 0.0024  memory: 999
# 04/28 18:28:07 - mmengine - INFO - Iter(val) [350/515]    eta: 0:00:08  time: 0.0495  data_time: 0.0023  memory: 999
# 04/28 18:28:09 - mmengine - INFO - Iter(val) [400/515]    eta: 0:00:06  time: 0.0491  data_time: 0.0023  memory: 999
# 04/28 18:28:12 - mmengine - INFO - Iter(val) [450/515]    eta: 0:00:03  time: 0.0513  data_time: 0.0028  memory: 999
# 04/28 18:28:14 - mmengine - INFO - Iter(val) [500/515]    eta: 0:00:00  time: 0.0507  data_time: 0.0029  memory: 999
# 04/28 18:28:15 - mmengine - INFO - per class results:
# 04/28 18:28:15 - mmengine - INFO -
# +------------+-------+-------+-------+--------+-----------+--------+
# |   Class    |  IoU  |  Acc  |  Dice | Fscore | Precision | Recall |
# +------------+-------+-------+-------+--------+-----------+--------+
# | background | 99.58 |  99.8 | 99.79 | 99.79  |   99.79   |  99.8  |
# | glomeruili | 74.69 | 85.24 | 85.51 | 85.51  |   85.78   | 85.24  |
# +------------+-------+-------+-------+--------+-----------+--------+
# 04/28 18:28:15 - mmengine - INFO - Iter(val) [515/515]    aAcc: 99.5900  mIoU: 87.1400  mAcc: 92.5200  mDice: 92.6500  mFscore: 92.6500  mPrecision: 92.7800  mRecall: 92.5200  data_time: 0.0029  time: 0.0523
# 04/28 18:28:26 - mmengine - INFO - Iter(train) [ 2050/24000]  lr: 9.5424e-03  eta: 1:20:39  time: 0.2180  data_time: 0.0100  memory: 3906  loss: 0.0251  decode.loss_ce: 0.0124  decode.loss_dice: 0.0039  decode.acc_seg: 99.1536  aux.loss_ce: 0.0065  aux.loss_dice: 0.0024  aux.acc_seg: 98.9395
# 04/28 18:28:37 - mmengine - INFO - Iter(train) [ 2100/24000]  lr: 9.5312e-03  eta: 1:20:27  time: 0.2182  data_time: 0.0100  memory: 3906  loss: 0.0472  decode.loss_ce: 0.0278  decode.loss_dice: 0.0054  decode.acc_seg: 99.9554  aux.loss_ce: 0.0115  aux.loss_dice: 0.0025  aux.acc_seg: 99.8838
# 04/28 18:28:48 - mmengine - INFO - Iter(train) [ 2150/24000]  lr: 9.5200e-03  eta: 1:20:16  time: 0.2171  data_time: 0.0107  memory: 3906  loss: 0.0176  decode.loss_ce: 0.0080  decode.loss_dice: 0.0030  decode.acc_seg: 99.7828  aux.loss_ce: 0.0047  aux.loss_dice: 0.0019  aux.acc_seg: 99.7358
# 04/28 18:28:59 - mmengine - INFO - Iter(train) [ 2200/24000]  lr: 9.5088e-03  eta: 1:20:04  time: 0.2167  data_time: 0.0103  memory: 3906  loss: 0.0233  decode.loss_ce: 0.0120  decode.loss_dice: 0.0034  decode.acc_seg: 98.5659  aux.loss_ce: 0.0060  aux.loss_dice: 0.0019  aux.acc_seg: 98.6861
# 04/28 18:29:10 - mmengine - INFO - Iter(train) [ 2250/24000]  lr: 9.4976e-03  eta: 1:19:52  time: 0.2196  data_time: 0.0107  memory: 3906  loss: 0.0225  decode.loss_ce: 0.0119  decode.loss_dice: 0.0032  decode.acc_seg: 99.0103  aux.loss_ce: 0.0053  aux.loss_dice: 0.0021  aux.acc_seg: 98.8271
# 04/28 18:29:21 - mmengine - INFO - Iter(train) [ 2300/24000]  lr: 9.4864e-03  eta: 1:19:40  time: 0.2193  data_time: 0.0120  memory: 3906  loss: 0.0352  decode.loss_ce: 0.0195  decode.loss_dice: 0.0049  decode.acc_seg: 99.7699  aux.loss_ce: 0.0084  aux.loss_dice: 0.0025  aux.acc_seg: 99.8078
# 04/28 18:29:31 - mmengine - INFO - Iter(train) [ 2350/24000]  lr: 9.4752e-03  eta: 1:19:28  time: 0.2169  data_time: 0.0109  memory: 3906  loss: 0.0225  decode.loss_ce: 0.0111  decode.loss_dice: 0.0035  decode.acc_seg: 100.0000  aux.loss_ce: 0.0058  aux.loss_dice: 0.0021  aux.acc_seg: 100.0000
# 04/28 18:29:42 - mmengine - INFO - Iter(train) [ 2400/24000]  lr: 9.4640e-03  eta: 1:19:16  time: 0.2190  data_time: 0.0116  memory: 3906  loss: 0.0185  decode.loss_ce: 0.0093  decode.loss_dice: 0.0033  decode.acc_seg: 99.2920  aux.loss_ce: 0.0041  aux.loss_dice: 0.0018  aux.acc_seg: 99.3242
# 04/28 18:29:42 - mmengine - INFO - Saving checkpoint at 2400 iterations
# 04/28 18:29:47 - mmengine - INFO - Iter(val) [ 50/515]    eta: 0:00:25  time: 0.0536  data_time: 0.0030  memory: 999
# 04/28 18:29:50 - mmengine - INFO - Iter(val) [100/515]    eta: 0:00:22  time: 0.0526  data_time: 0.0028  memory: 999
# 04/28 18:29:54 - mmengine - INFO - Iter(val) [150/515]    eta: 0:00:23  time: 0.0549  data_time: 0.0031  memory: 999
# 04/28 18:29:57 - mmengine - INFO - Iter(val) [200/515]    eta: 0:00:19  time: 0.0536  data_time: 0.0030  memory: 999
# 04/28 18:30:00 - mmengine - INFO - Iter(val) [250/515]    eta: 0:00:15  time: 0.0530  data_time: 0.0029  memory: 999
# 04/28 18:30:02 - mmengine - INFO - Iter(val) [300/515]    eta: 0:00:12  time: 0.0534  data_time: 0.0030  memory: 999
# 04/28 18:30:05 - mmengine - INFO - Iter(val) [350/515]    eta: 0:00:09  time: 0.0534  data_time: 0.0029  memory: 999
# 04/28 18:30:08 - mmengine - INFO - Iter(val) [400/515]    eta: 0:00:06  time: 0.0538  data_time: 0.0030  memory: 999
# 04/28 18:30:10 - mmengine - INFO - Iter(val) [450/515]    eta: 0:00:03  time: 0.0531  data_time: 0.0029  memory: 999
# 04/28 18:30:13 - mmengine - INFO - Iter(val) [500/515]    eta: 0:00:00  time: 0.0522  data_time: 0.0028  memory: 999
# 04/28 18:30:14 - mmengine - INFO - per class results:
# 04/28 18:30:14 - mmengine - INFO -
# +------------+-------+-------+-------+--------+-----------+--------+
# |   Class    |  IoU  |  Acc  |  Dice | Fscore | Precision | Recall |
# +------------+-------+-------+-------+--------+-----------+--------+
# | background | 99.58 | 99.78 | 99.79 | 99.79  |    99.8   | 99.78  |
# | glomeruili | 74.67 | 86.21 |  85.5 |  85.5  |   84.81   | 86.21  |
# +------------+-------+-------+-------+--------+-----------+--------+
# 04/28 18:30:14 - mmengine - INFO - Iter(val) [515/515]    aAcc: 99.5800  mIoU: 87.1300  mAcc: 92.9900  mDice: 92.6400  mFscore: 92.6400  mPrecision: 92.3000  mRecall: 92.9900  data_time: 0.0031  time: 0.0564
# 04/28 18:30:25 - mmengine - INFO - Iter(train) [ 2450/24000]  lr: 9.4528e-03  eta: 1:19:04  time: 0.2156  data_time: 0.0106  memory: 3906  loss: 0.0318  decode.loss_ce: 0.0168  decode.loss_dice: 0.0046  decode.acc_seg: 99.7619  aux.loss_ce: 0.0081  aux.loss_dice: 0.0023  aux.acc_seg: 99.7619
# 04/28 18:30:35 - mmengine - INFO - Iter(train) [ 2500/24000]  lr: 9.4416e-03  eta: 1:18:52  time: 0.2166  data_time: 0.0113  memory: 3906  loss: 0.0271  decode.loss_ce: 0.0141  decode.loss_dice: 0.0045  decode.acc_seg: 100.0000  aux.loss_ce: 0.0061  aux.loss_dice: 0.0023  aux.acc_seg: 100.0000
# 04/28 18:30:46 - mmengine - INFO - Iter(train) [ 2550/24000]  lr: 9.4303e-03  eta: 1:18:40  time: 0.2198  data_time: 0.0123  memory: 3906  loss: 0.0266  decode.loss_ce: 0.0142  decode.loss_dice: 0.0042  decode.acc_seg: 99.4974  aux.loss_ce: 0.0057  aux.loss_dice: 0.0025  aux.acc_seg: 99.4374
# 04/28 18:30:57 - mmengine - INFO - Iter(train) [ 2600/24000]  lr: 9.4191e-03  eta: 1:18:29  time: 0.2205  data_time: 0.0119  memory: 3906  loss: 0.0228  decode.loss_ce: 0.0113  decode.loss_dice: 0.0035  decode.acc_seg: 99.6905  aux.loss_ce: 0.0060  aux.loss_dice: 0.0020  aux.acc_seg: 99.5647
# 04/28 18:31:08 - mmengine - INFO - Iter(train) [ 2650/24000]  lr: 9.4079e-03  eta: 1:18:18  time: 0.2181  data_time: 0.0112  memory: 3906  loss: 0.0324  decode.loss_ce: 0.0163  decode.loss_dice: 0.0053  decode.acc_seg: 99.7866  aux.loss_ce: 0.0080  aux.loss_dice: 0.0028  aux.acc_seg: 99.7384
# 04/28 18:31:19 - mmengine - INFO - Iter(train) [ 2700/24000]  lr: 9.3967e-03  eta: 1:18:06  time: 0.2192  data_time: 0.0117  memory: 3906  loss: 0.0183  decode.loss_ce: 0.0088  decode.loss_dice: 0.0031  decode.acc_seg: 98.9638  aux.loss_ce: 0.0047  aux.loss_dice: 0.0018  aux.acc_seg: 99.3246
# 04/28 18:31:30 - mmengine - INFO - Iter(train) [ 2750/24000]  lr: 9.3855e-03  eta: 1:17:55  time: 0.2193  data_time: 0.0127  memory: 3906  loss: 0.0156  decode.loss_ce: 0.0079  decode.loss_dice: 0.0029  decode.acc_seg: 99.9233  aux.loss_ce: 0.0032  aux.loss_dice: 0.0016  aux.acc_seg: 99.6724
# 04/28 18:31:42 - mmengine - INFO - Iter(train) [ 2800/24000]  lr: 9.3743e-03  eta: 1:17:49  time: 0.2145  data_time: 0.0094  memory: 3906  loss: 0.0413  decode.loss_ce: 0.0236  decode.loss_dice: 0.0052  decode.acc_seg: 99.9944  aux.loss_ce: 0.0099  aux.loss_dice: 0.0026  aux.acc_seg: 99.9957
# 04/28 18:31:45 - mmengine - INFO - Iter(val) [ 50/515]    eta: 0:00:27  time: 0.0545  data_time: 0.0028  memory: 999
# 04/28 18:31:47 - mmengine - INFO - Iter(val) [100/515]    eta: 0:00:22  time: 0.0491  data_time: 0.0024  memory: 999
# 04/28 18:31:50 - mmengine - INFO - Iter(val) [150/515]    eta: 0:00:19  time: 0.0497  data_time: 0.0025  memory: 999
# 04/28 18:31:53 - mmengine - INFO - Iter(val) [200/515]    eta: 0:00:16  time: 0.0496  data_time: 0.0025  memory: 999
# 04/28 18:31:55 - mmengine - INFO - Iter(val) [250/515]    eta: 0:00:13  time: 0.0533  data_time: 0.0031  memory: 999
# 04/28 18:31:58 - mmengine - INFO - Iter(val) [300/515]    eta: 0:00:11  time: 0.0530  data_time: 0.0030  memory: 999
# 04/28 18:32:00 - mmengine - INFO - Iter(val) [350/515]    eta: 0:00:08  time: 0.0526  data_time: 0.0030  memory: 999
# 04/28 18:32:03 - mmengine - INFO - Iter(val) [400/515]    eta: 0:00:06  time: 0.0530  data_time: 0.0030  memory: 999
# 04/28 18:32:06 - mmengine - INFO - Iter(val) [450/515]    eta: 0:00:03  time: 0.0525  data_time: 0.0028  memory: 999
# 04/28 18:32:08 - mmengine - INFO - Iter(val) [500/515]    eta: 0:00:00  time: 0.0518  data_time: 0.0028  memory: 999
# 04/28 18:32:09 - mmengine - INFO - per class results:
# 04/28 18:32:09 - mmengine - INFO -
# +------------+-------+-------+-------+--------+-----------+--------+
# |   Class    |  IoU  |  Acc  |  Dice | Fscore | Precision | Recall |
# +------------+-------+-------+-------+--------+-----------+--------+
# | background | 98.58 | 100.0 | 99.28 | 99.28  |   98.58   | 100.0  |
# | glomeruili |  0.0  |  0.0  |  0.0  |  nan   |    nan    |  0.0   |
# +------------+-------+-------+-------+--------+-----------+--------+
# 04/28 18:32:09 - mmengine - INFO - Iter(val) [515/515]    aAcc: 98.5800  mIoU: 49.2900  mAcc: 50.0000  mDice: 49.6400  mFscore: 99.2800  mPrecision: 98.5800  mRecall: 50.0000  data_time: 0.0030  time: 0.0526
# 04/28 18:32:20 - mmengine - INFO - Iter(train) [ 2850/24000]  lr: 9.3630e-03  eta: 1:17:38  time: 0.2204  data_time: 0.0122  memory: 3906  loss: 0.0214  decode.loss_ce: 0.0110  decode.loss_dice: 0.0033  decode.acc_seg: 98.5025  aux.loss_ce: 0.0053  aux.loss_dice: 0.0018  aux.acc_seg: 99.0230
# 04/28 18:32:31 - mmengine - INFO - Iter(train) [ 2900/24000]  lr: 9.3518e-03  eta: 1:17:27  time: 0.2173  data_time: 0.0101  memory: 3906  loss: 0.0117  decode.loss_ce: 0.0050  decode.loss_dice: 0.0023  decode.acc_seg: 100.0000  aux.loss_ce: 0.0030  aux.loss_dice: 0.0015  aux.acc_seg: 99.9188
# 04/28 18:32:42 - mmengine - INFO - Iter(train) [ 2950/24000]  lr: 9.3406e-03  eta: 1:17:15  time: 0.2280  data_time: 0.0157  memory: 3906  loss: 0.0146  decode.loss_ce: 0.0072  decode.loss_dice: 0.0024  decode.acc_seg: 99.9592  aux.loss_ce: 0.0036  aux.loss_dice: 0.0014  aux.acc_seg: 99.8384
# 04/28 18:32:53 - mmengine - INFO - Exp name: pspnet_r50-d8_4xb2-40k_cityscapes-512x1024_20250428_181827
# 04/28 18:32:53 - mmengine - INFO - Iter(train) [ 3000/24000]  lr: 9.3294e-03  eta: 1:17:03  time: 0.2171  data_time: 0.0100  memory: 3906  loss: 0.0200  decode.loss_ce: 0.0098  decode.loss_dice: 0.0037  decode.acc_seg: 100.0000  aux.loss_ce: 0.0042  aux.loss_dice: 0.0023  aux.acc_seg: 99.9958
# 04/28 18:33:04 - mmengine - INFO - Iter(train) [ 3050/24000]  lr: 9.3182e-03  eta: 1:16:52  time: 0.2176  data_time: 0.0111  memory: 3906  loss: 0.0166  decode.loss_ce: 0.0084  decode.loss_dice: 0.0026  decode.acc_seg: 100.0000  aux.loss_ce: 0.0039  aux.loss_dice: 0.0016  aux.acc_seg: 100.0000
# 04/28 18:33:15 - mmengine - INFO - Iter(train) [ 3100/24000]  lr: 9.3069e-03  eta: 1:16:45  time: 0.2156  data_time: 0.0106  memory: 3906  loss: 0.0309  decode.loss_ce: 0.0165  decode.loss_dice: 0.0044  decode.acc_seg: 99.8656  aux.loss_ce: 0.0076  aux.loss_dice: 0.0023  aux.acc_seg: 99.8850
# 04/28 18:33:26 - mmengine - INFO - Iter(train) [ 3150/24000]  lr: 9.2957e-03  eta: 1:16:33  time: 0.2196  data_time: 0.0111  memory: 3906  loss: 0.0353  decode.loss_ce: 0.0184  decode.loss_dice: 0.0050  decode.acc_seg: 100.0000  aux.loss_ce: 0.0091  aux.loss_dice: 0.0028  aux.acc_seg: 100.0000
# 04/28 18:33:37 - mmengine - INFO - Iter(train) [ 3200/24000]  lr: 9.2845e-03  eta: 1:16:22  time: 0.2192  data_time: 0.0109  memory: 3906  loss: 0.0173  decode.loss_ce: 0.0091  decode.loss_dice: 0.0027  decode.acc_seg: 99.8327  aux.loss_ce: 0.0038  aux.loss_dice: 0.0016  aux.acc_seg: 99.8510
# 04/28 18:33:37 - mmengine - INFO - Saving checkpoint at 3200 iterations
# 04/28 18:33:43 - mmengine - INFO - Iter(val) [ 50/515]    eta: 0:00:26  time: 0.0554  data_time: 0.0027  memory: 999
# 04/28 18:33:46 - mmengine - INFO - Iter(val) [100/515]    eta: 0:00:24  time: 0.0578  data_time: 0.0027  memory: 999
# 04/28 18:33:49 - mmengine - INFO - Iter(val) [150/515]    eta: 0:00:20  time: 0.0579  data_time: 0.0032  memory: 999
# 04/28 18:33:51 - mmengine - INFO - Iter(val) [200/515]    eta: 0:00:18  time: 0.0595  data_time: 0.0036  memory: 999
# 04/28 18:33:54 - mmengine - INFO - Iter(val) [250/515]    eta: 0:00:15  time: 0.0580  data_time: 0.0031  memory: 999
# 04/28 18:33:57 - mmengine - INFO - Iter(val) [300/515]    eta: 0:00:12  time: 0.0570  data_time: 0.0030  memory: 999
# 04/28 18:34:00 - mmengine - INFO - Iter(val) [350/515]    eta: 0:00:09  time: 0.0517  data_time: 0.0026  memory: 999
# 04/28 18:34:02 - mmengine - INFO - Iter(val) [400/515]    eta: 0:00:06  time: 0.0526  data_time: 0.0027  memory: 999
# 04/28 18:34:05 - mmengine - INFO - Iter(val) [450/515]    eta: 0:00:03  time: 0.0522  data_time: 0.0026  memory: 999
# 04/28 18:34:08 - mmengine - INFO - Iter(val) [500/515]    eta: 0:00:00  time: 0.0522  data_time: 0.0028  memory: 999
# 04/28 18:34:09 - mmengine - INFO - per class results:
# 04/28 18:34:09 - mmengine - INFO -
# +------------+-------+-------+-------+--------+-----------+--------+
# |   Class    |  IoU  |  Acc  |  Dice | Fscore | Precision | Recall |
# +------------+-------+-------+-------+--------+-----------+--------+
# | background | 99.58 | 99.94 | 99.79 | 99.79  |   99.64   | 99.94  |
# | glomeruili | 72.28 | 75.31 | 83.91 | 83.91  |   94.72   | 75.31  |
# +------------+-------+-------+-------+--------+-----------+--------+
# 04/28 18:34:09 - mmengine - INFO - Iter(val) [515/515]    aAcc: 99.5900  mIoU: 85.9300  mAcc: 87.6200  mDice: 91.8500  mFscore: 91.8500  mPrecision: 97.1800  mRecall: 87.6200  data_time: 0.0032  time: 0.0557
# 04/28 18:34:20 - mmengine - INFO - Iter(train) [ 3250/24000]  lr: 9.2732e-03  eta: 1:16:12  time: 0.2226  data_time: 0.0127  memory: 3906  loss: 0.0172  decode.loss_ce: 0.0093  decode.loss_dice: 0.0029  decode.acc_seg: 99.9022  aux.loss_ce: 0.0035  aux.loss_dice: 0.0014  aux.acc_seg: 99.9034
# 04/28 18:34:31 - mmengine - INFO - Iter(train) [ 3300/24000]  lr: 9.2620e-03  eta: 1:16:00  time: 0.2204  data_time: 0.0101  memory: 3906  loss: 0.0171  decode.loss_ce: 0.0082  decode.loss_dice: 0.0026  decode.acc_seg: 99.8753  aux.loss_ce: 0.0046  aux.loss_dice: 0.0016  aux.acc_seg: 99.8753
# 04/28 18:34:42 - mmengine - INFO - Iter(train) [ 3350/24000]  lr: 9.2508e-03  eta: 1:15:49  time: 0.2190  data_time: 0.0100  memory: 3906  loss: 0.0137  decode.loss_ce: 0.0063  decode.loss_dice: 0.0028  decode.acc_seg: 99.9095  aux.loss_ce: 0.0029  aux.loss_dice: 0.0016  aux.acc_seg: 99.8933
# 04/28 18:34:53 - mmengine - INFO - Iter(train) [ 3400/24000]  lr: 9.2395e-03  eta: 1:15:38  time: 0.2197  data_time: 0.0111  memory: 3906  loss: 0.0145  decode.loss_ce: 0.0074  decode.loss_dice: 0.0026  decode.acc_seg: 99.7882  aux.loss_ce: 0.0031  aux.loss_dice: 0.0015  aux.acc_seg: 99.7585
# 04/28 18:35:04 - mmengine - INFO - Iter(train) [ 3450/24000]  lr: 9.2283e-03  eta: 1:15:27  time: 0.2216  data_time: 0.0113  memory: 3906  loss: 0.0300  decode.loss_ce: 0.0162  decode.loss_dice: 0.0042  decode.acc_seg: 99.9649  aux.loss_ce: 0.0076  aux.loss_dice: 0.0021  aux.acc_seg: 99.9668
# 04/28 18:35:15 - mmengine - INFO - Iter(train) [ 3500/24000]  lr: 9.2171e-03  eta: 1:15:18  time: 0.2133  data_time: 0.0080  memory: 3906  loss: 0.0185  decode.loss_ce: 0.0097  decode.loss_dice: 0.0027  decode.acc_seg: 97.7530  aux.loss_ce: 0.0045  aux.loss_dice: 0.0015  aux.acc_seg: 97.7537
# 04/28 18:35:26 - mmengine - INFO - Iter(train) [ 3550/24000]  lr: 9.2058e-03  eta: 1:15:06  time: 0.2159  data_time: 0.0092  memory: 3906  loss: 0.0333  decode.loss_ce: 0.0188  decode.loss_dice: 0.0042  decode.acc_seg: 99.8185  aux.loss_ce: 0.0082  aux.loss_dice: 0.0021  aux.acc_seg: 99.7694
# 04/28 18:35:37 - mmengine - INFO - Iter(train) [ 3600/24000]  lr: 9.1946e-03  eta: 1:14:54  time: 0.2217  data_time: 0.0105  memory: 3906  loss: 0.0213  decode.loss_ce: 0.0112  decode.loss_dice: 0.0033  decode.acc_seg: 99.7968  aux.loss_ce: 0.0051  aux.loss_dice: 0.0018  aux.acc_seg: 99.7509
# 04/28 18:35:40 - mmengine - INFO - Iter(val) [ 50/515]    eta: 0:00:26  time: 0.0532  data_time: 0.0028  memory: 999
# 04/28 18:35:42 - mmengine - INFO - Iter(val) [100/515]    eta: 0:00:22  time: 0.0558  data_time: 0.0030  memory: 999
# 04/28 18:35:45 - mmengine - INFO - Iter(val) [150/515]    eta: 0:00:19  time: 0.0537  data_time: 0.0029  memory: 999
# 04/28 18:35:48 - mmengine - INFO - Iter(val) [200/515]    eta: 0:00:17  time: 0.0532  data_time: 0.0029  memory: 999
# 04/28 18:35:50 - mmengine - INFO - Iter(val) [250/515]    eta: 0:00:14  time: 0.0527  data_time: 0.0029  memory: 999
# 04/28 18:35:53 - mmengine - INFO - Iter(val) [300/515]    eta: 0:00:11  time: 0.0529  data_time: 0.0029  memory: 999
# 04/28 18:35:56 - mmengine - INFO - Iter(val) [350/515]    eta: 0:00:08  time: 0.0535  data_time: 0.0029  memory: 999
# 04/28 18:35:58 - mmengine - INFO - Iter(val) [400/515]    eta: 0:00:06  time: 0.0520  data_time: 0.0028  memory: 999
# 04/28 18:36:01 - mmengine - INFO - Iter(val) [450/515]    eta: 0:00:03  time: 0.0522  data_time: 0.0028  memory: 999
# 04/28 18:36:04 - mmengine - INFO - Iter(val) [500/515]    eta: 0:00:00  time: 0.0522  data_time: 0.0028  memory: 999
# 04/28 18:36:04 - mmengine - INFO - per class results:
# 04/28 18:36:04 - mmengine - INFO -
# +------------+------+-------+-------+--------+-----------+--------+
# |   Class    | IoU  |  Acc  |  Dice | Fscore | Precision | Recall |
# +------------+------+-------+-------+--------+-----------+--------+
# | background | 99.5 | 99.94 | 99.75 | 99.75  |   99.56   | 99.94  |
# | glomeruili | 66.6 | 69.45 | 79.95 | 79.95  |   94.19   | 69.45  |
# +------------+------+-------+-------+--------+-----------+--------+
# 04/28 18:36:04 - mmengine - INFO - Iter(val) [515/515]    aAcc: 99.5000  mIoU: 83.0500  mAcc: 84.6900  mDice: 89.8500  mFscore: 89.8500  mPrecision: 96.8700  mRecall: 84.6900  data_time: 0.0031  time: 0.0534
# 04/28 18:36:15 - mmengine - INFO - Iter(train) [ 3650/24000]  lr: 9.1833e-03  eta: 1:14:43  time: 0.2180  data_time: 0.0112  memory: 3906  loss: 0.0247  decode.loss_ce: 0.0116  decode.loss_dice: 0.0040  decode.acc_seg: 99.9600  aux.loss_ce: 0.0069  aux.loss_dice: 0.0022  aux.acc_seg: 99.9385
# 04/28 18:36:26 - mmengine - INFO - Iter(train) [ 3700/24000]  lr: 9.1721e-03  eta: 1:14:31  time: 0.2148  data_time: 0.0082  memory: 3906  loss: 0.0173  decode.loss_ce: 0.0091  decode.loss_dice: 0.0026  decode.acc_seg: 98.7554  aux.loss_ce: 0.0041  aux.loss_dice: 0.0015  aux.acc_seg: 98.7087
# 04/28 18:36:37 - mmengine - INFO - Iter(train) [ 3750/24000]  lr: 9.1608e-03  eta: 1:14:19  time: 0.2164  data_time: 0.0090  memory: 3906  loss: 0.0144  decode.loss_ce: 0.0072  decode.loss_dice: 0.0023  decode.acc_seg: 99.9747  aux.loss_ce: 0.0035  aux.loss_dice: 0.0015  aux.acc_seg: 99.9992
# 04/28 18:36:48 - mmengine - INFO - Iter(train) [ 3800/24000]  lr: 9.1496e-03  eta: 1:14:07  time: 0.2190  data_time: 0.0111  memory: 3906  loss: 0.0184  decode.loss_ce: 0.0100  decode.loss_dice: 0.0026  decode.acc_seg: 100.0000  aux.loss_ce: 0.0043  aux.loss_dice: 0.0015  aux.acc_seg: 100.0000
# 04/28 18:36:59 - mmengine - INFO - Iter(train) [ 3850/24000]  lr: 9.1383e-03  eta: 1:13:56  time: 0.2177  data_time: 0.0103  memory: 3906  loss: 0.0255  decode.loss_ce: 0.0137  decode.loss_dice: 0.0042  decode.acc_seg: 99.7618  aux.loss_ce: 0.0055  aux.loss_dice: 0.0021  aux.acc_seg: 99.8011
# 04/28 18:37:11 - mmengine - INFO - Iter(train) [ 3900/24000]  lr: 9.1271e-03  eta: 1:13:52  time: 0.2197  data_time: 0.0114  memory: 3906  loss: 0.0149  decode.loss_ce: 0.0073  decode.loss_dice: 0.0030  decode.acc_seg: 99.7885  aux.loss_ce: 0.0031  aux.loss_dice: 0.0015  aux.acc_seg: 99.8730
# 04/28 18:37:22 - mmengine - INFO - Iter(train) [ 3950/24000]  lr: 9.1158e-03  eta: 1:13:40  time: 0.2194  data_time: 0.0106  memory: 3906  loss: 0.0134  decode.loss_ce: 0.0071  decode.loss_dice: 0.0022  decode.acc_seg: 99.4118  aux.loss_ce: 0.0028  aux.loss_dice: 0.0012  aux.acc_seg: 99.4042
# 04/28 18:37:33 - mmengine - INFO - Exp name: pspnet_r50-d8_4xb2-40k_cityscapes-512x1024_20250428_181827
# 04/28 18:37:33 - mmengine - INFO - Iter(train) [ 4000/24000]  lr: 9.1046e-03  eta: 1:13:30  time: 0.2205  data_time: 0.0101  memory: 3906  loss: 0.0191  decode.loss_ce: 0.0106  decode.loss_dice: 0.0025  decode.acc_seg: 100.0000  aux.loss_ce: 0.0047  aux.loss_dice: 0.0013  aux.acc_seg: 100.0000
# 04/28 18:37:33 - mmengine - INFO - Saving checkpoint at 4000 iterations
# 04/28 18:37:38 - mmengine - INFO - Iter(val) [ 50/515]    eta: 0:00:26  time: 0.0591  data_time: 0.0035  memory: 999
# 04/28 18:37:41 - mmengine - INFO - Iter(val) [100/515]    eta: 0:00:22  time: 0.0514  data_time: 0.0025  memory: 999
# 04/28 18:37:43 - mmengine - INFO - Iter(val) [150/515]    eta: 0:00:19  time: 0.0509  data_time: 0.0025  memory: 999
# 04/28 18:37:46 - mmengine - INFO - Iter(val) [200/515]    eta: 0:00:16  time: 0.0543  data_time: 0.0030  memory: 999
# 04/28 18:37:49 - mmengine - INFO - Iter(val) [250/515]    eta: 0:00:14  time: 0.0557  data_time: 0.0030  memory: 999
# 04/28 18:37:52 - mmengine - INFO - Iter(val) [300/515]    eta: 0:00:11  time: 0.0556  data_time: 0.0029  memory: 999
# 04/28 18:37:55 - mmengine - INFO - Iter(val) [350/515]    eta: 0:00:09  time: 0.0569  data_time: 0.0030  memory: 999
# 04/28 18:37:57 - mmengine - INFO - Iter(val) [400/515]    eta: 0:00:06  time: 0.0539  data_time: 0.0030  memory: 999
# 04/28 18:38:00 - mmengine - INFO - Iter(val) [450/515]    eta: 0:00:03  time: 0.0548  data_time: 0.0030  memory: 999
# 04/28 18:38:03 - mmengine - INFO - Iter(val) [500/515]    eta: 0:00:00  time: 0.0459  data_time: 0.0020  memory: 999
# 04/28 18:38:04 - mmengine - INFO - per class results:
# 04/28 18:38:04 - mmengine - INFO -
# +------------+-------+-------+-------+--------+-----------+--------+
# |   Class    |  IoU  |  Acc  |  Dice | Fscore | Precision | Recall |
# +------------+-------+-------+-------+--------+-----------+--------+
# | background | 99.63 |  99.9 | 99.82 | 99.82  |   99.73   |  99.9  |
# | glomeruili | 76.17 | 81.48 | 86.47 | 86.47  |   92.12   | 81.48  |
# +------------+-------+-------+-------+--------+-----------+--------+
# 04/28 18:38:04 - mmengine - INFO - Iter(val) [515/515]    aAcc: 99.6400  mIoU: 87.9000  mAcc: 90.6900  mDice: 93.1400  mFscore: 93.1400  mPrecision: 95.9300  mRecall: 90.6900  data_time: 0.0031  time: 0.0548
# 04/28 18:38:15 - mmengine - INFO - Iter(train) [ 4050/24000]  lr: 9.0933e-03  eta: 1:13:18  time: 0.2166  data_time: 0.0111  memory: 3906  loss: 0.0229  decode.loss_ce: 0.0126  decode.loss_dice: 0.0032  decode.acc_seg: 99.9830  aux.loss_ce: 0.0055  aux.loss_dice: 0.0016  aux.acc_seg: 99.9819
# 04/28 18:38:26 - mmengine - INFO - Iter(train) [ 4100/24000]  lr: 9.0821e-03  eta: 1:13:07  time: 0.2202  data_time: 0.0110  memory: 3906  loss: 0.0159  decode.loss_ce: 0.0080  decode.loss_dice: 0.0028  decode.acc_seg: 100.0000  aux.loss_ce: 0.0037  aux.loss_dice: 0.0015  aux.acc_seg: 100.0000
# 04/28 18:38:37 - mmengine - INFO - Iter(train) [ 4150/24000]  lr: 9.0708e-03  eta: 1:12:56  time: 0.2155  data_time: 0.0086  memory: 3906  loss: 0.0171  decode.loss_ce: 0.0090  decode.loss_dice: 0.0027  decode.acc_seg: 99.0436  aux.loss_ce: 0.0040  aux.loss_dice: 0.0014  aux.acc_seg: 98.9815
# 04/28 18:38:48 - mmengine - INFO - Iter(train) [ 4200/24000]  lr: 9.0595e-03  eta: 1:12:44  time: 0.2169  data_time: 0.0095  memory: 3906  loss: 0.0156  decode.loss_ce: 0.0083  decode.loss_dice: 0.0026  decode.acc_seg: 99.5963  aux.loss_ce: 0.0034  aux.loss_dice: 0.0013  aux.acc_seg: 99.4276
# 04/28 18:38:59 - mmengine - INFO - Iter(train) [ 4250/24000]  lr: 9.0483e-03  eta: 1:12:33  time: 0.2191  data_time: 0.0110  memory: 3906  loss: 0.0265  decode.loss_ce: 0.0134  decode.loss_dice: 0.0040  decode.acc_seg: 99.8328  aux.loss_ce: 0.0069  aux.loss_dice: 0.0022  aux.acc_seg: 99.5911
# 04/28 18:39:10 - mmengine - INFO - Iter(train) [ 4300/24000]  lr: 9.0370e-03  eta: 1:12:23  time: 0.2202  data_time: 0.0119  memory: 3906  loss: 0.0095  decode.loss_ce: 0.0041  decode.loss_dice: 0.0018  decode.acc_seg: 99.7776  aux.loss_ce: 0.0024  aux.loss_dice: 0.0012  aux.acc_seg: 99.7594
# 04/28 18:39:21 - mmengine - INFO - Iter(train) [ 4350/24000]  lr: 9.0257e-03  eta: 1:12:12  time: 0.2210  data_time: 0.0127  memory: 3906  loss: 0.0105  decode.loss_ce: 0.0052  decode.loss_dice: 0.0019  decode.acc_seg: 100.0000  aux.loss_ce: 0.0024  aux.loss_dice: 0.0011  aux.acc_seg: 100.0000
# ...
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       init_cfg={'type': 'Constant', 'val': 0, 'override': {'name': 'norm3'}}
#       (3): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       init_cfg={'type': 'Constant', 'val': 0, 'override': {'name': 'norm3'}}
#     )
#     (layer3): ResLayer(
#       (0): Bottleneck(
#         (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (cbam): CBAM(
#           (ca): ChannelAttention(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (max_pool): AdaptiveMaxPool2d(output_size=1)
#             (fc1): Conv2d(256, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (relu1): ReLU()
#             (fc2): Conv2d(16, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (sigmoid): Sigmoid()
#           )
#           (sa): SpatialAttention(
#             (conv1): Conv2d(2, 1, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), bias=False)
#             (sigmoid): Sigmoid()
#           )
#         )
#       )
#       init_cfg={'type': 'Constant', 'val': 0, 'override': {'name': 'norm3'}}
#       (1): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (cbam): CBAM(
#           (ca): ChannelAttention(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (max_pool): AdaptiveMaxPool2d(output_size=1)
#             (fc1): Conv2d(256, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (relu1): ReLU()
#             (fc2): Conv2d(16, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (sigmoid): Sigmoid()
#           )
#           (sa): SpatialAttention(
#             (conv1): Conv2d(2, 1, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), bias=False)
#             (sigmoid): Sigmoid()
#           )
#         )
#       )
#       init_cfg={'type': 'Constant', 'val': 0, 'override': {'name': 'norm3'}}
#       (2): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (cbam): CBAM(
#           (ca): ChannelAttention(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (max_pool): AdaptiveMaxPool2d(output_size=1)
#             (fc1): Conv2d(256, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (relu1): ReLU()
#             (fc2): Conv2d(16, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (sigmoid): Sigmoid()
#           )
#           (sa): SpatialAttention(
#             (conv1): Conv2d(2, 1, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), bias=False)
#             (sigmoid): Sigmoid()
#           )
#         )
#       )
#       init_cfg={'type': 'Constant', 'val': 0, 'override': {'name': 'norm3'}}
#       (3): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (cbam): CBAM(
#           (ca): ChannelAttention(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (max_pool): AdaptiveMaxPool2d(output_size=1)
#             (fc1): Conv2d(256, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (relu1): ReLU()
#             (fc2): Conv2d(16, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (sigmoid): Sigmoid()
#           )
#           (sa): SpatialAttention(
#             (conv1): Conv2d(2, 1, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), bias=False)
#             (sigmoid): Sigmoid()
#           )
#         )
#       )
#       init_cfg={'type': 'Constant', 'val': 0, 'override': {'name': 'norm3'}}
#       (4): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (cbam): CBAM(
#           (ca): ChannelAttention(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (max_pool): AdaptiveMaxPool2d(output_size=1)
#             (fc1): Conv2d(256, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (relu1): ReLU()
#             (fc2): Conv2d(16, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (sigmoid): Sigmoid()
#           )
#           (sa): SpatialAttention(
#             (conv1): Conv2d(2, 1, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), bias=False)
#             (sigmoid): Sigmoid()
#           )
#         )
#       )
#       init_cfg={'type': 'Constant', 'val': 0, 'override': {'name': 'norm3'}}
#       (5): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (cbam): CBAM(
#           (ca): ChannelAttention(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (max_pool): AdaptiveMaxPool2d(output_size=1)
#             (fc1): Conv2d(256, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (relu1): ReLU()
#             (fc2): Conv2d(16, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (sigmoid): Sigmoid()
#           )
#           (sa): SpatialAttention(
#             (conv1): Conv2d(2, 1, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), bias=False)
#             (sigmoid): Sigmoid()
#           )
#         )
#       )
#       init_cfg={'type': 'Constant', 'val': 0, 'override': {'name': 'norm3'}}
#     )
#     (layer4): ResLayer(
#       (0): Bottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (cbam): CBAM(
#           (ca): ChannelAttention(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (max_pool): AdaptiveMaxPool2d(output_size=1)
#             (fc1): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (relu1): ReLU()
#             (fc2): Conv2d(32, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (sigmoid): Sigmoid()
#           )
#           (sa): SpatialAttention(
#             (conv1): Conv2d(2, 1, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), bias=False)
#             (sigmoid): Sigmoid()
#           )
#         )
#       )
#       init_cfg={'type': 'Constant', 'val': 0, 'override': {'name': 'norm3'}}
#       (1): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(4, 4), dilation=(4, 4), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (cbam): CBAM(
#           (ca): ChannelAttention(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (max_pool): AdaptiveMaxPool2d(output_size=1)
#             (fc1): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (relu1): ReLU()
#             (fc2): Conv2d(32, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (sigmoid): Sigmoid()
#           )
#           (sa): SpatialAttention(
#             (conv1): Conv2d(2, 1, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), bias=False)
#             (sigmoid): Sigmoid()
#           )
#         )
#       )
#       init_cfg={'type': 'Constant', 'val': 0, 'override': {'name': 'norm3'}}
#       (2): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(4, 4), dilation=(4, 4), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (cbam): CBAM(
#           (ca): ChannelAttention(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (max_pool): AdaptiveMaxPool2d(output_size=1)
#             (fc1): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (relu1): ReLU()
#             (fc2): Conv2d(32, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (sigmoid): Sigmoid()
#           )
#           (sa): SpatialAttention(
#             (conv1): Conv2d(2, 1, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), bias=False)
#             (sigmoid): Sigmoid()
#           )
#         )
#       )
#       init_cfg={'type': 'Constant', 'val': 0, 'override': {'name': 'norm3'}}
#     )
#   )
#   init_cfg=[{'type': 'Kaiming', 'layer': 'Conv2d'}, {'type': 'Constant', 'val': 1, 'layer': ['_BatchNorm', 'GroupNorm']}]
#   (decode_head): PSPHead(
#     input_transform=None, ignore_index=255, align_corners=False
#     (loss_decode): ModuleList(
#       (0): CrossEntropyLoss(avg_non_ignore=False)
#       (1): DiceLoss()
#     )
#     (conv_seg): Conv2d(512, 2, kernel_size=(1, 1), stride=(1, 1))
#     (dropout): Dropout2d(p=0.1, inplace=False)
#     (psp_modules): PPM(
#       (0): Sequential(
#         (0): AdaptiveAvgPool2d(output_size=1)
#         (1): ConvModule(
#           (conv): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (activate): ReLU(inplace=True)
#         )
#       )
#       (1): Sequential(
#         (0): AdaptiveAvgPool2d(output_size=2)
#         (1): ConvModule(
#           (conv): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (activate): ReLU(inplace=True)
#         )
#       )
#       (2): Sequential(
#         (0): AdaptiveAvgPool2d(output_size=3)
#         (1): ConvModule(
#           (conv): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (activate): ReLU(inplace=True)
#         )
#       )
#       (3): Sequential(
#         (0): AdaptiveAvgPool2d(output_size=6)
#         (1): ConvModule(
#           (conv): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (activate): ReLU(inplace=True)
#         )
#       )
#     )
#     (bottleneck): ConvModule(
#       (conv): Conv2d(4096, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (activate): ReLU(inplace=True)
#     )
#   )
#   init_cfg={'type': 'Normal', 'std': 0.01, 'override': {'name': 'conv_seg'}}
#   (auxiliary_head): FCNHead(
#     input_transform=None, ignore_index=255, align_corners=False
#     (loss_decode): ModuleList(
#       (0): CrossEntropyLoss(avg_non_ignore=False)
#       (1): DiceLoss()
#     )
#     (conv_seg): Conv2d(256, 2, kernel_size=(1, 1), stride=(1, 1))
#     (dropout): Dropout2d(p=0.1, inplace=False)
#     (convs): Sequential(
#       (0): ConvModule(
#         (conv): Conv2d(1024, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (activate): ReLU(inplace=True)
#       )
#     )
#   )
#   init_cfg={'type': 'Normal', 'std': 0.01, 'override': {'name': 'conv_seg'}}
# )
